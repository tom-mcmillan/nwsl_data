# %%
# Import what's available
from fbref_match_downloader import quick_download, FBRefMatchDownloader
import os

# Your match IDs
match_ids = [
    'f8177893',
    '7ac1c0c8',
    '83edc9ff',
    'd0426a07',
    'b9cf7980'
]

# Check what's already downloaded (if any)
downloaded = []
if os.path.exists('match_html_files'):
    downloaded = [f.replace('match_', '').replace('.html', '') 
                  for f in os.listdir('match_html_files') 
                  if f.startswith('match_') and f.endswith('.html')]
    print(f"Already downloaded: {downloaded}")

# Filter to only download missing matches
remaining_matches = [m for m in match_ids if m not in downloaded]
print(f"\nTotal matches: {len(match_ids)}")
print(f"Already downloaded: {len(downloaded)}")
print(f"Remaining to download: {len(remaining_matches)}")
print(f"Match IDs to download: {remaining_matches}")

# Download with anti-blocking measures
if remaining_matches:
    print("\nStarting download with anti-blocking measures...")
    print("(6-12 second delays, break every 2 downloads)")
    
    results = quick_download(
        remaining_matches,
        min_delay=6.0,      # 6-12 seconds between requests
        max_delay=12.0,
        batch_size=2        # Break every 2 downloads
    )
    
    # Show results
    print("\n" + "="*50)
    successful = sum(1 for r in results if r['status'] == 'success')
    failed = sum(1 for r in results if r['status'] != 'success')
    print(f"Download complete!")
    print(f"✓ Successful: {successful}")
    print(f"✗ Failed: {failed}")
    
    # Show individual results
    print("\nDetailed results:")
    for r in results:
        status_icon = "✓" if r['status'] == 'success' else "✗"
        print(f"  {status_icon} {r['match_id']}: {r['status']}")
else:
    print("\nAll matches already downloaded! Nothing to do.")
# Out:
# Already downloaded: ['7284c984', '6a57c82e', 'd0426a07', '8883ea79', '81481f61', 'fb569f13', '83edc9ff', '5c187984', 'eb172ca3', 'd5615e5b', '064fab50']
#
# Total matches: 5
# Already downloaded: 11
# Remaining to download: 3
# Match IDs to download: ['f8177893', '7ac1c0c8', 'b9cf7980']
#
# Starting download with anti-blocking measures...
# (6-12 second delays, break every 2 downloads)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 34
#      31 print("\nStarting download with anti-blocking measures...")
#      32 print("(6-12 second delays, break every 2 downloads)")
# ---> 34 results = quick_download(
#      35     remaining_matches,
#      36     min_delay=6.0,      # 6-12 seconds between requests
#      37     max_delay=12.0,
#      38     batch_size=2        # Break every 2 downloads
#      39 )
#      41 # Show results
#      42 print("\n" + "="*50)
#
# TypeError: quick_download() got an unexpected keyword argument 'min_delay'

# %%
# Import and check the function signature
from fbref_match_downloader import quick_download, FBRefMatchDownloader
import os
import inspect

# Check what parameters quick_download accepts
print("quick_download function signature:")
print(inspect.signature(quick_download))
print("\n" + "="*50 + "\n")

# Your match IDs
match_ids = [
    'f8177893',
    '7ac1c0c8',
    '83edc9ff',
    'd0426a07',
    'b9cf7980'
]

# Check what's already downloaded
downloaded = []
if os.path.exists('match_html_files'):
    downloaded = [f.replace('match_', '').replace('.html', '') 
                  for f in os.listdir('match_html_files') 
                  if f.startswith('match_') and f.endswith('.html')]

# Filter remaining matches
remaining_matches = [m for m in match_ids if m not in downloaded]
print(f"Remaining to download: {remaining_matches}")

# Option 1: Try quick_download with just the match_ids
if remaining_matches:
    try:
        print("\nAttempting download with quick_download...")
        results = quick_download(remaining_matches)
    except Exception as e:
        print(f"Error with quick_download: {e}")
        
        # Option 2: Use FBRefMatchDownloader directly
        print("\nUsing FBRefMatchDownloader directly...")
        downloader = FBRefMatchDownloader(
            min_delay=6.0,
            max_delay=12.0,
            batch_size=2
        )
        results = downloader.download_multiple_matches(remaining_matches)
    
    # Show results
    print("\n" + "="*50)
    successful = sum(1 for r in results if r['status'] == 'success')
    failed = sum(1 for r in results if r['status'] != 'success')
    print(f"✓ Successful: {successful}")
    print(f"✗ Failed: {failed}")
    
    for r in results:
        status_icon = "✓" if r['status'] == 'success' else "✗"
        print(f"  {status_icon} {r['match_id']}: {r['status']}")
else:
    print("\nAll matches already downloaded!")
# Out:
# quick_download function signature:
# (match_ids: List[str], use_selenium: bool = False, extract_tables: bool = False)
#
# ==================================================
#
# Remaining to download: ['f8177893', '7ac1c0c8', 'b9cf7980']
#
# Attempting download with quick_download...
# Starting download of 3 matches...
# Files will be saved to: /Users/thomasmcmillan/projects/nwsl_data/notebooks/match_html_files/
# Download method: BeautifulSoup with Selenium fallback
# --------------------------------------------------
#
# [1/3] Downloading match f8177893...
# Detected dynamic content, switching to Selenium...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_f8177893.html (method: selenium_dynamic)
#
# [2/3] Downloading match 7ac1c0c8...
# Detected dynamic content, switching to Selenium...
# Using Selenium for dynamic content...
# Selenium download error: HTTPConnectionPool(host='localhost', port=52448): Read timed out. (read timeout=120)
#
# [3/3] Downloading match b9cf7980...
# Detected dynamic content, switching to Selenium...
# Using Selenium for dynamic content...
# Selenium download error: HTTPConnectionPool(host='localhost', port=52448): Read timed out. (read timeout=120)
#
# ==================================================
# Download Summary:
#   ✓ Successful: 1
#   ✗ Not found: 0
#   ✗ Errors: 2
#   Total: 3
#
# Methods used:
#   - selenium_dynamic: 1
#
# Summary saved to: match_html_files/download_summary.json
#
# ==================================================
# ✓ Successful: 1
# ✗ Failed: 2
#   ✓ f8177893: success
#   ✗ 7ac1c0c8: error
#   ✗ b9cf7980: error

# %%
from fbref_match_downloader import quick_download
import os

# Your match IDs
match_ids = [
    '1a01081c',
    'b9cf7980',
    '0e4932ff',
    '12c17fb7',
    '8640ac6f',
    '2d03d5bd'
]


# Check what's already downloaded
downloaded = []
if os.path.exists('match_html_files'):
    downloaded = [f.replace('match_', '').replace('.html', '') 
                  for f in os.listdir('match_html_files') 
                  if f.startswith('match_') and f.endswith('.html')]
    print(f"Already downloaded: {len(downloaded)} matches")
    print(f"Downloaded: {downloaded}")

# Filter remaining matches
remaining_matches = [m for m in match_ids if m not in downloaded]
print(f"\nRemaining to download: {remaining_matches}")
print(f"Number of matches to download: {len(remaining_matches)}")

# Download with Selenium and table extraction
if remaining_matches:
    print("\n" + "="*50)
    print("Starting download with:")
    print("- Selenium (FORCED)")
    print("- Table extraction (ENABLED)")
    print("="*50 + "\n")
    
    # Use quick_download with Selenium and table extraction
    results = quick_download(
        remaining_matches,
        use_selenium=True,      # Force Selenium
        extract_tables=True     # Extract tables
    )
    
    # Show results
    print("\n" + "="*50)
    print("Download complete!")
    
    # Count successes
    if results:
        successful = sum(1 for r in results if r.get('status') == 'success')
        failed = len(results) - successful
        print(f"✓ Successful: {successful}")
        print(f"✗ Failed: {failed}")
        
        # Show details
        print("\nDetailed results:")
        for r in results:
            status = r.get('status', 'unknown')
            match_id = r.get('match_id', 'unknown')
            status_icon = "✓" if status == 'success' else "✗"
            print(f"  {status_icon} {match_id}: {status}")
            if status == 'success' and 'tables_extracted' in r:
                print(f"     Tables extracted: {len(r['tables_extracted'])}")
else:
    print("\nAll matches already downloaded!")

print("\n" + "="*50)
print("✓ HTML files saved in: match_html_files/")
print("✓ CSV tables saved in: match_html_files/tables/[match_id]/")
# Out:
# Already downloaded: 14 matches
# Downloaded: ['7284c984', 'b9cf7980', '6a57c82e', 'f8177893', 'd0426a07', '8883ea79', '81481f61', 'fb569f13', '7ac1c0c8', '83edc9ff', '5c187984', 'eb172ca3', 'd5615e5b', '064fab50']
#
# Remaining to download: ['1a01081c', '0e4932ff', '12c17fb7', '8640ac6f', '2d03d5bd']
# Number of matches to download: 5
#
# ==================================================
# Starting download with:
# - Selenium (FORCED)
# - Table extraction (ENABLED)
# ==================================================
#
# Starting download of 5 matches...
# Files will be saved to: /Users/thomasmcmillan/projects/nwsl_data/notebooks/match_html_files/
# Download method: Selenium (forced)
# --------------------------------------------------
#
# [1/5] Downloading match 1a01081c...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_1a01081c.html (method: selenium)
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: keeper_stats_8e306dc6
#   Extracted table: stats_257fad2b_summary
#   Extracted table: keeper_stats_257fad2b
#
# [2/5] Downloading match 0e4932ff...
# Using Selenium for dynamic content...
# Selenium download error: HTTPConnectionPool(host='localhost', port=60819): Read timed out. (read timeout=120)
#
# [3/5] Downloading match 12c17fb7...
# Using Selenium for dynamic content...
# Selenium download error: HTTPConnectionPool(host='localhost', port=60819): Read timed out. (read timeout=120)
#
# [4/5] Downloading match 8640ac6f...
# Using Selenium for dynamic content...
# Selenium download error: HTTPConnectionPool(host='localhost', port=60819): Read timed out. (read timeout=120)
#
# [5/5] Downloading match 2d03d5bd...
# Using Selenium for dynamic content...
# Selenium download error: HTTPConnectionPool(host='localhost', port=60819): Read timed out. (read timeout=120)
#
# ==================================================
# Download Summary:
#   ✓ Successful: 1
#   ✗ Not found: 0
#   ✗ Errors: 4
#   Total: 5
#
# Methods used:
#   - selenium: 1
#
# Summary saved to: match_html_files/download_summary.json
#
# ==================================================
# Download complete!
# ✓ Successful: 1
# ✗ Failed: 4
#
# Detailed results:
#   ✓ 1a01081c: success
#      Tables extracted: 4
#   ✗ 0e4932ff: error
#   ✗ 12c17fb7: error
#   ✗ 8640ac6f: error
#   ✗ 2d03d5bd: error
#
# ==================================================
# ✓ HTML files saved in: match_html_files/
# ✓ CSV tables saved in: match_html_files/tables/[match_id]/

# %%
from fbref_match_downloader import FBRefMatchDownloader
import os
import time

# Match IDs that failed
failed_matches = ['0e4932ff', '12c17fb7', '8640ac6f', '2d03d5bd']

print(f"Retrying {len(failed_matches)} failed matches...")
print("Using fresh Selenium instance for each match\n")

# Download each match individually with its own driver
results = []
for i, match_id in enumerate(failed_matches, 1):
    print(f"[{i}/{len(failed_matches)}] Downloading {match_id}...")
    
    try:
        # Create a fresh downloader for each match
        downloader = FBRefMatchDownloader(use_selenium=True)
        
        # Download single match
        result = downloader.download_match_html(
            match_id,
            output_dir='match_html_files',
            extract_tables=True
        )
        
        results.append(result)
        
        # Clean up driver immediately
        if hasattr(downloader, 'driver') and downloader.driver:
            downloader.driver.quit()
        
        if result['status'] == 'success':
            print(f"✓ Success! Tables extracted: {len(result.get('tables_extracted', []))}")
        else:
            print(f"✗ Failed: {result.get('error', 'Unknown error')}")
        
        # Wait between downloads
        if i < len(failed_matches):
            wait_time = 10
            print(f"Waiting {wait_time} seconds before next download...\n")
            time.sleep(wait_time)
            
    except Exception as e:
        print(f"✗ Exception: {e}")
        results.append({'match_id': match_id, 'status': 'error', 'error': str(e)})

# Summary
print("\n" + "="*50)
successful = sum(1 for r in results if r.get('status') == 'success')
print(f"Retry complete!")
print(f"✓ Successful: {successful}/{len(failed_matches)}")
print(f"✗ Failed: {len(failed_matches) - successful}/{len(failed_matches)}")
# Out:
# Retrying 4 failed matches...
# Using fresh Selenium instance for each match
#
# [1/4] Downloading 0e4932ff...
# Downloading match 0e4932ff...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_0e4932ff.html (method: selenium)
#   Extracted table: stats_5f911568_summary
#   Extracted table: keeper_stats_5f911568
#   Extracted table: stats_64c362f2_summary
#   Extracted table: keeper_stats_64c362f2
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds before next download...
#
# [2/4] Downloading 12c17fb7...
# Downloading match 12c17fb7...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_12c17fb7.html (method: selenium)
#   Extracted table: stats_d976a235_summary
#   Extracted table: keeper_stats_d976a235
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: keeper_stats_df9a10a1
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds before next download...
#
# [3/4] Downloading 8640ac6f...
# Downloading match 8640ac6f...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_8640ac6f.html (method: selenium)
#   Extracted table: stats_257fad2b_summary
#   Extracted table: keeper_stats_257fad2b
#   Extracted table: stats_e442aad0_summary
#   Extracted table: keeper_stats_e442aad0
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds before next download...
#
# [4/4] Downloading 2d03d5bd...
# Downloading match 2d03d5bd...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_2d03d5bd.html (method: selenium)
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: keeper_stats_df9a10a1
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: keeper_stats_8e306dc6
# ✓ Success! Tables extracted: 4
#
# ==================================================
# Retry complete!
# ✓ Successful: 4/4
# ✗ Failed: 0/4

# %%
from fbref_match_downloader import FBRefMatchDownloader
import os
import time
from datetime import datetime

def download_match_batch(match_ids, batch_name="Batch"):
    """
    Download a batch of matches with Selenium, skipping already downloaded ones.
    """
    # Check what's already downloaded
    downloaded = []
    if os.path.exists('match_html_files'):
        downloaded = [f.replace('match_', '').replace('.html', '') 
                      for f in os.listdir('match_html_files') 
                      if f.startswith('match_') and f.endswith('.html')]
    
    # Filter to only new matches
    new_matches = [m for m in match_ids if m not in downloaded]
    skipped = [m for m in match_ids if m in downloaded]
    
    print(f"\n{'='*60}")
    print(f"{batch_name} - {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"{'='*60}")
    print(f"Total matches provided: {len(match_ids)}")
    print(f"Already downloaded (skipping): {len(skipped)}")
    print(f"New matches to download: {len(new_matches)}")
    
    if not new_matches:
        print("\n✓ All matches already downloaded! Nothing to do.")
        return []
    
    print(f"\nDownloading: {', '.join(new_matches)}")
    print("Using fresh Selenium instance for each match\n")
    
    # Download each match
    results = []
    start_time = time.time()
    
    for i, match_id in enumerate(new_matches, 1):
        print(f"[{i}/{len(new_matches)}] Downloading {match_id}...")
        
        try:
            downloader = FBRefMatchDownloader(use_selenium=True)
            result = downloader.download_match_html(
                match_id,
                output_dir='match_html_files',
                extract_tables=True
            )
            results.append(result)
            
            if hasattr(downloader, 'driver') and downloader.driver:
                downloader.driver.quit()
            
            if result['status'] == 'success':
                print(f"✓ Success! Tables extracted: {len(result.get('tables_extracted', []))}")
            else:
                print(f"✗ Failed: {result.get('error', 'Unknown error')}")
            
            if i < len(new_matches):
                print(f"Waiting 10 seconds...\n")
                time.sleep(10)
                
        except Exception as e:
            print(f"✗ Exception: {e}")
            results.append({'match_id': match_id, 'status': 'error', 'error': str(e)})
    
    # Summary
    elapsed = time.time() - start_time
    successful = sum(1 for r in results if r.get('status') == 'success')
    
    print(f"\n{'='*60}")
    print(f"Batch complete! Time: {int(elapsed//60)}m {int(elapsed%60)}s")
    print(f"✓ Successful: {successful}/{len(new_matches)}")
    print(f"✗ Failed: {len(new_matches) - successful}/{len(new_matches)}")
    print('='*60)
    
    return results

# YOUR MATCH IDs HERE - Change these to whatever matches you want



# Run the download
if match_ids:
    results = download_match_batch(match_ids, "My Batch")
else:
    print("Please add match IDs to the list above!")
# Out:
# ============================================================
# My Batch - 2025-07-27 20:01:16
# ============================================================
# Total matches provided: 99
# Already downloaded (skipping): 0
# New matches to download: 99
#
# Downloading: f881e2c1, 60f738e9, c472965f, 5d762423, 478694f8, c6e91034, 6d73cf64, 520134f4, 170d1dda, c78c16a1, 9dcf496b, 418e0e31, 3c2a99b1, e4c6e5a2, e38fdb0f, db1b8928, f7ec5018, e01f2ab2, 85ea774d, 611eb468, 1b276643, 3f955256, 4874cbfb, 60713322, f13fd918, 29994120, 6c10cfdb, 3b6c58de, 0ab262a8, d8f2bb6c, 4ccba30d, b2f4ab2b, 541a43ed, 53d69588, fb3fee9e, d68ba0d9, 070a85c6, 0ac89923, 55840597, 0438ac6f, 5cbe3ea6, 2124d8de, 6c1960fe, ad4385ca, ca6b1e40, 9eae33e6, 0349e876, f4e707e7, bd617704, b3536acf, a8e5bb48, 1a84f24d, bd7ec044, 7f3417a9, caadbdc9, 7439eff5, 55934b05, 6c066abf, 0e7fddc2, 45ea9030, 61cc1e00, 565b1da5, 2d678cba, 889e323c, f5582e60, 502ff272, 5c3b3b7a, 2bda25a1, 5ff5843f, 7aa0733c, dc4da4e7, 88db5cc5, decc5784, 1cf24c9d, bc51c892, 50bd521d, 7239cc9a, 1bb660c2, ade5efdc, 573e3558, 6c0afe0b, fd03e664, 99b29ebc, 6fd000ec, 708f6bbe, 707d1ba5, 252a6a92, 266fc787, 08df8ebf, 5191e299, be554b90, 5fe1d504, 093ed426, 9bd6f453, c09cea95, 0b641a7e, ff1e7c30, a0486da6, 2a7d2195
# Using fresh Selenium instance for each match
#
# [1/99] Downloading f881e2c1...
# Downloading match f881e2c1...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_f881e2c1.html (method: selenium)
#   Extracted table: stats_257fad2b_summary
#   Extracted table: keeper_stats_257fad2b
#   Extracted table: stats_e442aad0_summary
#   Extracted table: keeper_stats_e442aad0
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [2/99] Downloading 60f738e9...
# Downloading match 60f738e9...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_60f738e9.html (method: selenium)
#   Extracted table: stats_257fad2b_summary
#   Extracted table: stats_64c362f2_summary
# ✓ Success! Tables extracted: 2
# Waiting 10 seconds...
#
# [3/99] Downloading c472965f...
# Downloading match c472965f...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_c472965f.html (method: selenium)
#   Extracted table: stats_e813709a_summary
#   Extracted table: stats_e442aad0_summary
# ✓ Success! Tables extracted: 2
# Waiting 10 seconds...
#
# [4/99] Downloading 5d762423...
# Downloading match 5d762423...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_5d762423.html (method: selenium)
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: stats_ab757728_summary
# ✓ Success! Tables extracted: 2
# Waiting 10 seconds...
#
# [5/99] Downloading 478694f8...
# Downloading match 478694f8...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_478694f8.html (method: selenium)
#   Extracted table: stats_257fad2b_summary
#   Extracted table: stats_5f911568_summary
# ✓ Success! Tables extracted: 2
# Waiting 10 seconds...
#
# [6/99] Downloading c6e91034...
# Downloading match c6e91034...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_c6e91034.html (method: selenium)
#   Extracted table: stats_64c362f2_summary
#   Extracted table: stats_8e306dc6_summary
# ✓ Success! Tables extracted: 2
# Waiting 10 seconds...
#
# [7/99] Downloading 6d73cf64...
# Downloading match 6d73cf64...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_6d73cf64.html (method: selenium)
#   Extracted table: stats_e442aad0_summary
#   Extracted table: stats_64c362f2_summary
# ✓ Success! Tables extracted: 2
# Waiting 10 seconds...
#
# [8/99] Downloading 520134f4...
# Downloading match 520134f4...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_520134f4.html (method: selenium)
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: stats_e813709a_summary
# ✓ Success! Tables extracted: 2
# Waiting 10 seconds...
#
# [9/99] Downloading 170d1dda...
# Downloading match 170d1dda...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match
html (method: selenium)
#   Extracted table: stats_257fad2b_summary
#   Extracted table: keeper_stats_257fad2b
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: keeper_stats_8e306dc6
# ✓ Success! Tables extracted: 4
#
# ============================================================
# Batch complete! Time: 28m 29s
# ✓ Successful: 98/99
# ✗ Failed: 1/99
# ============================================================

# %%
from fbref_match_downloader import FBRefMatchDownloader
import os
import time
from datetime import datetime

def download_match_batch(match_ids, batch_name="Batch"):
    """
    Download a batch of matches with Selenium, skipping already downloaded ones.
    """
    # Check what's already downloaded
    downloaded = []
    if os.path.exists('match_html_files'):
        downloaded = [f.replace('match_', '').replace('.html', '') 
                      for f in os.listdir('match_html_files') 
                      if f.startswith('match_') and f.endswith('.html')]
    
    # Filter to only new matches
    new_matches = [m for m in match_ids if m not in downloaded]
    skipped = [m for m in match_ids if m in downloaded]
    
    print(f"\n{'='*60}")
    print(f"{batch_name} - {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"{'='*60}")
    print(f"Total matches provided: {len(match_ids)}")
    print(f"Already downloaded (skipping): {len(skipped)}")
    print(f"New matches to download: {len(new_matches)}")
    
    if not new_matches:
        print("\n✓ All matches already downloaded! Nothing to do.")
        return []
    
    print(f"\nDownloading: {', '.join(new_matches)}")
    print("Using fresh Selenium instance for each match\n")
    
    # Download each match
    results = []
    start_time = time.time()
    
    for i, match_id in enumerate(new_matches, 1):
        print(f"[{i}/{len(new_matches)}] Downloading {match_id}...")
        
        try:
            downloader = FBRefMatchDownloader(use_selenium=True)
            result = downloader.download_match_html(
                match_id,
                output_dir='match_html_files',
                extract_tables=True
            )
            results.append(result)
            
            if hasattr(downloader, 'driver') and downloader.driver:
                downloader.driver.quit()
            
            if result['status'] == 'success':
                print(f"✓ Success! Tables extracted: {len(result.get('tables_extracted', []))}")
            else:
                print(f"✗ Failed: {result.get('error', 'Unknown error')}")
            
            if i < len(new_matches):
                print(f"Waiting 10 seconds...\n")
                time.sleep(10)
                
        except Exception as e:
            print(f"✗ Exception: {e}")
            results.append({'match_id': match_id, 'status': 'error', 'error': str(e)})
    
    # Summary
    elapsed = time.time() - start_time
    successful = sum(1 for r in results if r.get('status') == 'success')
    
    print(f"\n{'='*60}")
    print(f"Batch complete! Time: {int(elapsed//60)}m {int(elapsed%60)}s")
    print(f"✓ Successful: {successful}/{len(new_matches)}")
    print(f"✗ Failed: {len(new_matches) - successful}/{len(new_matches)}")
    print('='*60)
    
    return results

# YOUR MATCH IDs HERE - Change these to whatever matches you want






# Run the download
if match_ids:
    results = download_match_batch(match_ids, "My Batch")
else:
    print("Please add match IDs to the list above!")
# Out:
# ============================================================
# My Batch - 2025-07-27 21:16:35
# ============================================================
# Total matches provided: 200
# Already downloaded (skipping): 0
# New matches to download: 200
#
# Downloading: cfce4a7e, 60c0fef2, eb7f25b6, e0a6d860, 64ae00a8, bde14f5d, ab51dc2a, a0785409, b14ef42f, aae9acb9, 5ecc20d9, 657ab5b5, 2bbf11bc, 258598f2, 9f6d6df5, 0d86f760, 2d9e0ef0, 11e0e304, 9fa14fb5, 40d29f66, 2f8861a3, beaa3276, ba8ffe87, 72856ea5, 169816e4, aae24672, 6ff06b8e, e1e5105f, 625276de, cb36f524, b8918216, 554b360b, 6245629c, 18fdb801, 83e9f6cd, 391bfb7d, 49e5362d, 34a9f7eb, e493bc1b, 78894a6f, eaf0b116, ba381725, acf83533, 5ada410d, 21aac0ca, 02765e6d, bc4d18e2, 14d766d0, d1f5bba9, 563b9572, c919bc72, 94916b48, d6daa6a9, 8aa2a6b5, 20f76f42, 9f3f16bd, 
...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_9c06de8d.html (method: selenium)
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: keeper_stats_8e306dc6
#   Extracted table: stats_d4c130bc_summary
#   Extracted table: keeper_stats_d4c130bc
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [169/200] Downloading f1ce78a1...
# Downloading match f1ce78a1...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_f1ce78a1.html (method: selenium)
#   Extracted table: stats_e442aad0_summary
#   Extracted table: keeper_stats_e442aad0
#   Extracted table: stats_d976a235_summary
#   Extracted table: keeper_stats_d976a235
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [170/200] Downloading bf237d24...
# Downloading match bf237d24...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_bf237d24.html (method: selenium)
#   Extracted table: stats_e813709a_summary
#   Extracted table: keeper_stats_e813709a
#   Extracted table: stats_85c458aa_summary
#   Extracted table: keeper_stats_85c458aa
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [171/200] Downloading 8f38f319...
# Downloading match 8f38f319...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_8f38f319.html (method: selenium)
#   Extracted table: stats_257fad2b_summary
#   Extracted table: keeper_stats_257fad2b
#   Extracted table: stats_2a6178ac_summary
#   Extracted table: keeper_stats_2a6178ac
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [172/200] Downloading 2d29c0fd...
# Downloading match 2d29c0fd...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_2d29c0fd.html (method: selenium)
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: keeper_stats_8e306dc6
#   Extracted table: stats_e442aad0_summary
#   Extracted table: keeper_stats_e442aad0
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [173/200] Downloading 2fd28c8a...
# Downloading match 2fd28c8a...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_2fd28c8a.html (method: selenium)
#   Extracted table: stats_e442aad0_summary
#   Extracted table: keeper_stats_e442aad0
#   Extracted table: stats_257fad2b_summary
#   Extracted table: keeper_stats_257fad2b
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [174/200] Downloading 5360f412...
# Downloading match 5360f412...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_5360f412.html (method: selenium)
#   Extracted table: stats_85c458aa_summary
#   Extracted table: keeper_stats_85c458aa
#   Extracted table: stats_d4c130bc_summary
#   Extracted table: keeper_stats_d4c130bc
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [175/200] Downloading 51a251e2...
# Downloading match 51a251e2...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_51a251e2.html (method: selenium)
#   Extracted table: stats_2a6178ac_summary
#   Extracted table: keeper_stats_2a6178ac
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: keeper_stats_8e306dc6
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [176/200] Downloading 4f767234...
# Downloading match 4f767234...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_4f767234.html (method: selenium)
#   Extracted table: stats_d976a235_summary
#   Extracted table: keeper_stats_d976a235
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: keeper_stats_df9a10a1
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [177/200] Downloading 10edb34e...
# Downloading match 10edb34e...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_10edb34e.html (method: selenium)
#   Extracted table: stats_e813709a_summary
#   Extracted table: keeper_stats_e813709a
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: keeper_stats_df9a10a1
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [178/200] Downloading 1ff11e78...
# Downloading match 1ff11e78...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_1ff11e78.html (method: selenium)
#   Extracted table: stats_257fad2b_summary
#   Extracted table: keeper_stats_257fad2b
#   Extracted table: stats_85c458aa_summary
#   Extracted table: keeper_stats_85c458aa
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [179/200] Downloading 9d12b00f...
# Downloading match 9d12b00f...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_9d12b00f.html (method: selenium)
#   Extracted table: stats_e442aad0_summary
#   Extracted table: keeper_stats_e442aad0
#   Extracted table: stats_2a6178ac_summary
#   Extracted table: keeper_stats_2a6178ac
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [180/200] Downloading f27037ec...
# Downloading match f27037ec...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_f27037ec.html (method: selenium)
#   Extracted table: stats_d976a235_summary
#   Extracted table: keeper_stats_d976a235
#   Extracted table: stats_d4c130bc_summary
#   Extracted table: keeper_stats_d4c130bc
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [181/200] Downloading 0790a1bc...
# Downloading match 0790a1bc...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_0790a1bc.html (method: selenium)
#   Extracted table: stats_2a6178ac_summary
#   Extracted table: keeper_stats_2a6178ac
#   Extracted table: stats_e813709a_summary
#   Extracted table: keeper_stats_e813709a
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [182/200] Downloading 3adf7469...
# Downloading match 3adf7469...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_3adf7469.html (method: selenium)
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: keeper_stats_df9a10a1
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: keeper_stats_8e306dc6
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [183/200] Downloading 1e7cfb64...
# Downloading match 1e7cfb64...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_1e7cfb64.html (method: selenium)
#   Extracted table: stats_d4c130bc_summary
#   Extracted table: keeper_stats_d4c130bc
#   Extracted table: stats_257fad2b_summary
#   Extracted table: keeper_stats_257fad2b
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [184/200] Downloading bc4c3562...
# Downloading match bc4c3562...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_bc4c3562.html (method: selenium)
#   Extracted table: stats_2a6178ac_summary
#   Extracted table: keeper_stats_2a6178ac
#   Extracted table: stats_85c458aa_summary
#   Extracted table: keeper_stats_85c458aa
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [185/200] Downloading 31b27eae...
# Downloading match 31b27eae...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_31b27eae.html (method: selenium)
#   Extracted table: stats_257fad2b_summary
#   Extracted table: keeper_stats_257fad2b
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: keeper_stats_df9a10a1
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [186/200] Downloading d2459fcd...
# Downloading match d2459fcd...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_d2459fcd.html (method: selenium)
#   Extracted table: stats_d4c130bc_summary
#   Extracted table: keeper_stats_d4c130bc
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: keeper_stats_8e306dc6
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [187/200] Downloading 94508a03...
# Downloading match 94508a03...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_94508a03.html (method: selenium)
#   Extracted table: stats_d976a235_summary
#   Extracted table: keeper_stats_d976a235
#   Extracted table: stats_e442aad0_summary
#   Extracted table: keeper_stats_e442aad0
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [188/200] Downloading 66ccdb0a...
# Downloading match 66ccdb0a...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_66ccdb0a.html (method: selenium)
#   Extracted table: stats_85c458aa_summary
#   Extracted table: keeper_stats_85c458aa
#   Extracted table: stats_d976a235_summary
#   Extracted table: keeper_stats_d976a235
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [189/200] Downloading 4aa78b99...
# Downloading match 4aa78b99...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_4aa78b99.html (method: selenium)
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: keeper_stats_df9a10a1
#   Extracted table: stats_d4c130bc_summary
#   Extracted table: keeper_stats_d4c130bc
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [190/200] Downloading cd4fe8d3...
# Downloading match cd4fe8d3...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_cd4fe8d3.html (method: selenium)
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: keeper_stats_8e306dc6
#   Extracted table: stats_d976a235_summary
#   Extracted table: keeper_stats_d976a235
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [191/200] Downloading e87befd2...
# Downloading match e87befd2...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_e87befd2.html (method: selenium)
#   Extracted table: stats_2a6178ac_summary
#   Extracted table: keeper_stats_2a6178ac
#   Extracted table: stats_e442aad0_summary
#   Extracted table: keeper_stats_e442aad0
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [192/200] Downloading a61b70d1...
# Downloading match a61b70d1...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_a61b70d1.html (method: selenium)
#   Extracted table: stats_257fad2b_summary
#   Extracted table: keeper_stats_257fad2b
#   Extracted table: stats_e813709a_summary
#   Extracted table: keeper_stats_e813709a
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [193/200] Downloading cd5433b9...
# Downloading match cd5433b9...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_cd5433b9.html (method: selenium)
#   Extracted table: stats_85c458aa_summary
#   Extracted table: keeper_stats_85c458aa
#   Extracted table: stats_e442aad0_summary
#   Extracted table: keeper_stats_e442aad0
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [194/200] Downloading b5da8f35...
# Downloading match b5da8f35...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_b5da8f35.html (method: selenium)
#   Extracted table: stats_257fad2b_summary
#   Extracted table: keeper_stats_257fad2b
#   Extracted table: stats_d4c130bc_summary
#   Extracted table: keeper_stats_d4c130bc
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [195/200] Downloading 8fcf96e7...
# Downloading match 8fcf96e7...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_8fcf96e7.html (method: selenium)
#   Extracted table: stats_e813709a_summary
#   Extracted table: keeper_stats_e813709a
#   Extracted table: stats_2a6178ac_summary
#   Extracted table: keeper_stats_2a6178ac
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [196/200] Downloading 74151c11...
# Downloading match 74151c11...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_74151c11.html (method: selenium)
#   Extracted table: stats_d4c130bc_summary
#   Extracted table: keeper_stats_d4c130bc
#   Extracted table: stats_2a6178ac_summary
#   Extracted table: keeper_stats_2a6178ac
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [197/200] Downloading 874207c8...
# Downloading match 874207c8...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_874207c8.html (method: selenium)
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: keeper_stats_8e306dc6
#   Extracted table: stats_85c458aa_summary
#   Extracted table: keeper_stats_85c458aa
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [198/200] Downloading 53526198...
# Downloading match 53526198...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_53526198.html (method: selenium)
#   Extracted table: stats_d976a235_summary
#   Extracted table: keeper_stats_d976a235
#   Extracted table: stats_257fad2b_summary
#   Extracted table: keeper_stats_257fad2b
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [199/200] Downloading eddbe752...
# Downloading match eddbe752...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_eddbe752.html (method: selenium)
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: keeper_stats_df9a10a1
#   Extracted table: stats_e813709a_summary
#   Extracted table: keeper_stats_e813709a
# ✓ Success! Tables extracted: 4
# Waiting 10 seconds...
#
# [200/200] Downloading f25117a0...
# Downloading match f25117a0...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_f25117a0.html (method: selenium)
#   Extracted table: stats_d4c130bc_summary
#   Extracted table: keeper_stats_d4c130bc
#   Extracted table: stats_85c458aa_summary
#   Extracted table: keeper_stats_85c458aa
# ✓ Success! Tables extracted: 4
#
# ============================================================
# Batch complete! Time: 131m 0s
# ✓ Successful: 198/200
# ✗ Failed: 2/200
# ============================================================

# %%
from fbref_match_downloader import FBRefMatchDownloader
import os
import time
from datetime import datetime

def download_match_batch(match_ids, batch_name="Batch"):
    """
    Download a batch of matches with Selenium, skipping already downloaded ones.
    """
    # Check what's already downloaded
    downloaded = []
    if os.path.exists('match_html_files'):
        downloaded = [f.replace('match_', '').replace('.html', '') 
                      for f in os.listdir('match_html_files') 
                      if f.startswith('match_') and f.endswith('.html')]
    
    # Filter to only new matches
    new_matches = [m for m in match_ids if m not in downloaded]
    skipped = [m for m in match_ids if m in downloaded]
    
    print(f"\n{'='*60}")
    print(f"{batch_name} - {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"{'='*60}")
    print(f"Total matches provided: {len(match_ids)}")
    print(f"Already downloaded (skipping): {len(skipped)}")
    print(f"New matches to download: {len(new_matches)}")
    
    if not new_matches:
        print("\n✓ All matches already downloaded! Nothing to do.")
        return []
    
    print(f"\nDownloading: {', '.join(new_matches)}")
    print("Using fresh Selenium instance for each match\n")
    
    # Download each match
    results = []
    start_time = time.time()
    
    for i, match_id in enumerate(new_matches, 1):
        print(f"[{i}/{len(new_matches)}] Downloading {match_id}...")
        
        try:
            downloader = FBRefMatchDownloader(use_selenium=True)
            result = downloader.download_match_html(
                match_id,
                output_dir='match_html_files',
                extract_tables=True
            )
            results.append(result)
            
            if hasattr(downloader, 'driver') and downloader.driver:
                downloader.driver.quit()
            
            if result['status'] == 'success':
                print(f"✓ Success! Tables extracted: {len(result.get('tables_extracted', []))}")
            else:
                print(f"✗ Failed: {result.get('error', 'Unknown error')}")
            
            if i < len(new_matches):
                print(f"Waiting 10 seconds...\n")
                time.sleep(10)
                
        except Exception as e:
            print(f"✗ Exception: {e}")
            results.append({'match_id': match_id, 'status': 'error', 'error': str(e)})
    
    # Summary
    elapsed = time.time() - start_time
    successful = sum(1 for r in results if r.get('status') == 'success')
    
    print(f"\n{'='*60}")
    print(f"Batch complete! Time: {int(elapsed//60)}m {int(elapsed%60)}s")
    print(f"✓ Successful: {successful}/{len(new_matches)}")
    print(f"✗ Failed: {len(new_matches) - successful}/{len(new_matches)}")
    print('='*60)
    
    return results

# YOUR MATCH IDs HERE - Change these to whatever matches you want
match_ids = [
    '84d6dca9', 'f36366a9', 'f542d0eb', '21526888', '55471e47', 'f7ee4334', '09657304',
    '5f19ba81', 'e1e516b9', '465459ea', '6e0ca93c', '50f8bec2', '58d26f0b', '30406f36',
    'adcabd51', 'ec411397', 'c0b6a639', '605fa6ac', 'd33ff0d8', '15f03025', '5238c761',
    '39dbe62f', 'f484f6f6', '5a7b7125', 'db9ea114', '092fe7ea', '783a65d6', 'e6091451',
    'e6d49a20', '16744a84', 'e17daaeb', '2c32f3d3', '22f04f44', 'afcd583a', '67a57f59',
    'c9ec6863', '25004f7e', '9bf95ec5', '70b9c1b6', '87083ab3', 'b66598e4', 'ff7f188e',
    '8780d6a5', 'b87d86b7', 'ae49ad75', '85ba8579', 'efddeda8', 'af3f157d', '5394bc1b',
    '36c46e0d', 'd53451cf', '86b6cc0a', '9a2b26a1', '23114faa', '37be7787', 'd26ed7f0',
    '7f398f88', 'cc8ebaaa', '0f1cb3d1', 'c79ee9c4', '4120af97', '622f898e', 'f8c8aea4',
    '6420bec8', '610a4c17', '1cef5979', '888d23a0', 'bde3da3d', 'f7b69a29', '6f3dc675',
    'ec9ceb9f', '1e61252e', 'eb81709b', '7ee309e3', 'b30b11e9', '05482155', '49094e3a',
    '745bedf3', '1520b6f5', 'b2b9405a', '0262bb35', '51020dea', '8f3fbf96', '78fac894',
    '2b75137d', 'efcbf7b7', '4f5b874c', 'dbbdb47c', '6c56c1c8', 'e133d584', '38048580',
    '125df7bb', 'f7ea6cf4', '01cdf2c9', '3e2273da', 'a0c570ff', '3903be81', '453b20ed',
    '3690a734', '073975b1', '6d4a68e6', 'e4dad184', '202faad2', '67076783', '4aa7a9c5',
    '6536d5aa', 'a6063bfa', 'e554a812', '976b8d77', 'a0d14941', 'ef3f22f7', '3b62060e',
    '6f44cb0a', '3e58ee5e', '2f8d4701', '6e16e67b', 'dd37453e', 'aa5085c0', 'b31185f6',
    '4d435ae3', 'fdd56674', '508e1cf0', '8b7900bd', '1173feeb', 'd6124086', '03f02a2d',
    'fba4e358', '1b8fd283', '2c25dcc1', '96746e28', '3653dfaf', 'f33364ee', '4a9bc623',
    'f2a8492d', 'd7245076', '731bfd8e', 'a6299d40', 'b3dca21a', '840ceaac', '3ccbf5a1',
    '9e58d38e', '6b7e06cd', '51f18293', '9f7344bb', '760a26e0', '477d8522', 'da5a0e99',
    '93804b58', '722a085f', 'b4d1565f', '26684b63', '610f69dd', '67a5da46', '74ed987d',
    'bfbad8e1', '3266a287', 'b0f251bd', '6c66219b', '705aeb44', '338f179a', '1ff4035b',
    '5edbe8f5', 'b4606770', '8ecc4297', '2dc93287', 'a172e221', 'cdde1e7a', '0550dc14',
    '2330e071', '9ea41f98', '27bba0f5', 'f7ab07b4', '81c16cad', '362bd167', '341cb0c8',
    '9a9a656b', 'afbff619', '47752024', 'eb4022c0', '640d698b', 'e7d9f27c', 'dc7cc573',
    '7f16970d', '794f4ccf', 'bffd3e4c', '24ddd8b3', 'f0a6559b', '051a8bb7', '06d86a41',
    '8d61a870', '7a7e6622', '8f77608d', '1d2f9fad', 'cd30a848', '7f8b4663', 'f6d763ba',
    'b67be4fe', 'e97c6f39', '3f04a185', '73ff619b', '57b30c8a', '2a0b287c', '7837616f', 
    'e0ef83c8', '888fb121', '119eeed3', '92ccc792', 'bf8c7152',
    '072e422f', '2e23bf3e', '14b12758', '78660c17', '76f87d7e', '6ba30741', 'c1330700', 'b34794ed',
    'b23322de', '9733a93c', 'a5d7e67a', '28529cef', 'be723b18', '2184074e', 'adffaaa7', '0ec1b5bb',
    'fb5d227f', 'b161f09c', '5a27b398', 'c19e2edc', '55fd0afd', '7d903802', '1011f557', '8acfa339',
    '74666aca', 'b818bb1d', '671d9115', '5648dd0c', '0f623827', '9f0e821c', '5dceef91', 'f29a7ef1',
    '481dcee5', '2cd4ec75', '10f108c3', '40d971e5', 'db88df87', '3548ce5a', '4ce881eb', 'ab0a3b8e',
    'f8ee8767', '9b3974b4', 'fa5f28b6', '08a226bf', '753a54ab', '151a8c6c', '138422ad', '986e95dc',
    '2a4f95fc', 'c3692424', '29064988', 'c17893bb', 'b2fdb217', '9a7e9c60', '80ff5d48', '57127901',
    'f832fee9', '4d241e61', 'e45b356c', '5c64fc50', 'a81c893d', 'b4cacaf2', '2b4a0943', 'fe50bdd7',
    'cd6d5b4f', 'd6f7c3b8', '0e889e55', 'bfd1ee7c', '9eace85e', 'c08ebbce', '664107de', 'cb653ae5',
    '2164c947', '03f56ad5', '15d59878', '7d3be8a8', 'da8e116e', '0603e751', '73672411', '5a2a2730',
    'f87a6d18', 'd437189b', '5fef737e', '66eef21d', '70f6ed43', 'e96c892d', '87c96d20', 'd711b57e',
    'f168f5b1', '4158fb00', 'f61689bf', '7239a666', '5f6913d7', '008e301f', '45ad1c98', '0194ccbe',
    '7958f078', 'a4bd2b1e', '26889552', '0a35cfd4', 'a19ff7be', '2f0f155c', 'b7b3a204', '96890718',
    'a38568cb', '0877e051', '74349bed', '475a847a', '9ae009b7', '9e867b88', 'fb58cf7f', 'c8df78e2',
    'dd55cdd7', 'd0b68db4', '733e8be0', '3d114ae2', '031916dc', '71e1c7c8', '12b89923', 'f09b4cef',
    'ecbd2ae5', 'ba2ade47', 'd7e4972c', '0fbbc32f', '414d2972', '903440ae', '20423258', '592098e0',
    '7eff59ff', '64bc17e9', 'dd365af8', '1c087799', '8fc9e8b7', '0cf23a87', 'c0cb6fdc', '13e27d90',
    '56095b7f', 'f513c5f3', 'd19e8e40', '07c68416', '2f764197', '3329a1cc', '03442e78', '6a832d3c',
    '92952d3a', '383bbe06', '70ffc3bc', '6c8777ca', 'd2545219', '42890885', 'edb68a59', 'b2aea0ed',
    '5d73d536', 'eb55dce7', '79cbcac5', 'd174fd4f', 'b6095527', '30adae5d', '11e533b1', '39bffb5e',
    '60b53e0c', '4013be4a', '810cc4f5', '726a91eb', '230c5ecb', '60a0c5a1', '2e27ac56', 'ac197aa2',
    '11ec0554', 'fc4833e0', '30d6a0e0', 'f06ed457', '692f1ab8', '91373610', '548d019f', '612a6c4c',
    '6be469ca', '14bc0f9a', 'd40c64aa', 'c56678cf'
]

# Run the download
if match_ids:
    results = download_match_batch(match_ids, "My Batch")
else:
    print("Please add match IDs to the list above!")
# Out:
# ============================================================
# My Batch - 2025-07-27 23:44:35
# ============================================================
# Total matches provided: 964
# Already downloaded (skipping): 0
# New matches to download: 964
#
# Downloading: 84d6dca9, f36366a9, f542d0eb, 21526888, 55471e47, f7ee4334, 09657304, 5f19ba81, e1e516b9, 465459ea, 6e0ca93c, 50f8bec2, 58d26f0b, 30406f36, adcabd51, ec411397, c0b6a639, 605fa6ac, d33ff0d8, 15f03025, 5238c761, 39dbe62f, f484f6f6, 5a7b7125, db9ea114, 092fe7ea, 783a65d6, e6091451, e6d49a20, 16744a84, e17daaeb, 2c32f3d3, 22f04f44, afcd583a, 67a57f59, c9ec6863, 25004f7e, 9bf95ec5, 70b9c1b6, 87083ab3, b66598e4, ff7f188e, 8780d6a5, b87d86b7, ae49ad75, 85ba8579, efddeda8, af3f157d, 5394bc1b, 36c46e0d, d53451cf, 86b6cc0a, 9a2b26a1, 23114faa, 37be7787, d26ed7f0, 7f398f88, cc8ebaaa, 0f1cb3d1, c79ee9c4, 4120af97, 622f898e, f8c8aea4, 6420b

# Using Selenium for dynamic content...
# ✓ Successfully saved: match_b87d86b7.html (method: selenium)
#   Extracted table: stats_d976a235_summary
#   Extracted table: stats_d976a235_passing
#   Extracted table: stats_d976a235_passing_types
#   Extracted table: stats_d976a235_defense
#   Extracted table: stats_d976a235_possession
#   Extracted table: stats_d976a235_misc
#   Extracted table: keeper_stats_d976a235
#   Extracted table: stats_257fad2b_summary
#   Extracted table: stats_257fad2b_passing
#   Extracted table: stats_257fad2b_passing_types
#   Extracted table: stats_257fad2b_defense
#   Extracted table: stats_257fad2b_possession
#   Extracted table: stats_257fad2b_misc
#   Extracted table: keeper_stats_257fad2b
#   Extracted table: shots_all
#   Extracted table: shots_d976a235
#   Extracted table: shots_257fad2b
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [45/964] Downloading ae49ad75...
# Downloading match ae49ad75...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_ae49ad75.html (method: selenium)
#   Extracted table: stats_e813709a_summary
#   Extracted table: stats_e813709a_passing
#   Extracted table: stats_e813709a_passing_types
#   Extracted table: stats_e813709a_defense
#   Extracted table: stats_e813709a_possession
#   Extracted table: stats_e813709a_misc
#   Extracted table: keeper_stats_e813709a
#   Extracted table: stats_85c458aa_summary
#   Extracted table: stats_85c458aa_passing
#   Extracted table: stats_85c458aa_passing_types
#   Extracted table: stats_85c458aa_defense
#   Extracted table: stats_85c458aa_possession
#   Extracted table: stats_85c458aa_misc
#   Extracted table: keeper_stats_85c458aa
#   Extracted table: shots_all
#   Extracted table: shots_e813709a
#   Extracted table: shots_85c458aa
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [46/964] Downloading 85ba8579...
# Downloading match 85ba8579...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_85ba8579.html (method: selenium)
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: stats_8e306dc6_passing
#   Extracted table: stats_8e306dc6_passing_types
#   Extracted table: stats_8e306dc6_defense
#   Extracted table: stats_8e306dc6_possession
#   Extracted table: stats_8e306dc6_misc
#   Extracted table: keeper_stats_8e306dc6
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: stats_df9a10a1_passing
#   Extracted table: stats_df9a10a1_passing_types
#   Extracted table: stats_df9a10a1_defense
#   Extracted table: stats_df9a10a1_possession
#   Extracted table: stats_df9a10a1_misc
#   Extracted table: keeper_stats_df9a10a1
#   Extracted table: shots_all
#   Extracted table: shots_8e306dc6
#   Extracted table: shots_df9a10a1
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [47/964] Downloading efddeda8...
# Downloading match efddeda8...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_efddeda8.html (method: selenium)
#   Extracted table: stats_d4c130bc_summary
#   Extracted table: stats_d4c130bc_passing
#   Extracted table: stats_d4c130bc_passing_types
#   Extracted table: stats_d4c130bc_defense
#   Extracted table: stats_d4c130bc_possession
#   Extracted table: stats_d4c130bc_misc
#   Extracted table: keeper_stats_d4c130bc
#   Extracted table: stats_d976a235_summary
#   Extracted table: stats_d976a235_passing
#   Extracted table: stats_d976a235_passing_types
#   Extracted table: stats_d976a235_defense
#   Extracted table: stats_d976a235_possession
#   Extracted table: stats_d976a235_misc
#   Extracted table: keeper_stats_d976a235
#   Extracted table: shots_all
#   Extracted table: shots_d4c130bc
#   Extracted table: shots_d976a235
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [48/964] Downloading af3f157d...
# Downloading match af3f157d...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_af3f157d.html (method: selenium)
#   Extracted table: stats_e442aad0_summary
#   Extracted table: stats_e442aad0_passing
#   Extracted table: stats_e442aad0_passing_types
#   Extracted table: stats_e442aad0_defense
#   Extracted table: stats_e442aad0_possession
#   Extracted table: stats_e442aad0_misc
#   Extracted table: keeper_stats_e442aad0
#   Extracted table: stats_257fad2b_summary
#   Extracted table: stats_257fad2b_passing
#   Extracted table: stats_257fad2b_passing_types
#   Extracted table: stats_257fad2b_defense
#   Extracted table: stats_257fad2b_possession
#   Extracted table: stats_257fad2b_misc
#   Extracted table: keeper_stats_257fad2b
#   Extracted table: shots_all
#   Extracted table: shots_e442aad0
#   Extracted table: shots_257fad2b
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [49/964] Downloading 5394bc1b...
# Downloading match 5394bc1b...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_5394bc1b.html (method: selenium)
#   Extracted table: stats_85c458aa_summary
#   Extracted table: stats_85c458aa_passing
#   Extracted table: stats_85c458aa_passing_types
#   Extracted table: stats_85c458aa_defense
#   Extracted table: stats_85c458aa_possession
#   Extracted table: stats_85c458aa_misc
#   Extracted table: keeper_stats_85c458aa
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: stats_8e306dc6_passing
#   Extracted table: stats_8e306dc6_passing_types
#   Extracted table: stats_8e306dc6_defense
#   Extracted table: stats_8e306dc6_possession
#   Extracted table: stats_8e306dc6_misc
#   Extracted table: keeper_stats_8e306dc6
#   Extracted table: shots_all
#   Extracted table: shots_85c458aa
#   Extracted table: shots_8e306dc6
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [50/964] Downloading 36c46e0d...
# Downloading match 36c46e0d...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_36c46e0d.html (method: selenium)
#   Extracted table: stats_e813709a_summary
#   Extracted table: stats_e813709a_passing
#   Extracted table: stats_e813709a_passing_types
#   Extracted table: stats_e813709a_defense
#   Extracted table: stats_e813709a_possession
#   Extracted table: stats_e813709a_misc
#   Extracted table: keeper_stats_e813709a
#   Extracted table: stats_2a6178ac_summary
#   Extracted table: stats_2a6178ac_passing
#   Extracted table: stats_2a6178ac_passing_types
#   Extracted table: stats_2a6178ac_defense
#   Extracted table: stats_2a6178ac_possession
#   Extracted table: stats_2a6178ac_misc
#   Extracted table: keeper_stats_2a6178ac
#   Extracted table: shots_all
#   Extracted table: shots_e813709a
#   Extracted table: shots_2a6178ac
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [51/964] Downloading d53451cf...
# Downloading match d53451cf...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_d53451cf.html (method: selenium)
#   Extracted table: stats_d4c130bc_summary
#   Extracted table: stats_d4c130bc_passing
#   Extracted table: stats_d4c130bc_passing_types
#   Extracted table: stats_d4c130bc_defense
#   Extracted table: stats_d4c130bc_possession
#   Extracted table: stats_d4c130bc_misc
#   Extracted table: keeper_stats_d4c130bc
#   Extracted table: stats_e813709a_summary
#   Extracted table: stats_e813709a_passing
#   Extracted table: stats_e813709a_passing_types
#   Extracted table: stats_e813709a_defense
#   Extracted table: stats_e813709a_possession
#   Extracted table: stats_e813709a_misc
#   Extracted table: keeper_stats_e813709a
#   Extracted table: shots_all
#   Extracted table: shots_d4c130bc
#   Extracted table: shots_e813709a
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [52/964] Downloading 86b6cc0a...
# Downloading match 86b6cc0a...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_86b6cc0a.html (method: selenium)
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: stats_8e306dc6_passing
#   Extracted table: stats_8e306dc6_passing_types
#   Extracted table: stats_8e306dc6_defense
#   Extracted table: stats_8e306dc6_possession
#   Extracted table: stats_8e306dc6_misc
#   Extracted table: keeper_stats_8e306dc6
#   Extracted table: stats_e442aad0_summary
#   Extracted table: stats_e442aad0_passing
#   Extracted table: stats_e442aad0_passing_types
#   Extracted table: stats_e442aad0_defense
#   Extracted table: stats_e442aad0_possession
#   Extracted table: stats_e442aad0_misc
#   Extracted table: keeper_stats_e442aad0
#   Extracted table: shots_all
#   Extracted table: shots_8e306dc6
#   Extracted table: shots_e442aad0
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [53/964] Downloading 9a2b26a1...
# Downloading match 9a2b26a1...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_9a2b26a1.html (method: selenium)
#   Extracted table: stats_2a6178ac_summary
#   Extracted table: stats_2a6178ac_passing
#   Extracted table: stats_2a6178ac_passing_types
#   Extracted table: stats_2a6178ac_defense
#   Extracted table: stats_2a6178ac_possession
#   Extracted table: stats_2a6178ac_misc
#   Extracted table: keeper_stats_2a6178ac
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: stats_df9a10a1_passing
#   Extracted table: stats_df9a10a1_passing_types
#   Extracted table: stats_df9a10a1_defense
#   Extracted table: stats_df9a10a1_possession
#   Extracted table: stats_df9a10a1_misc
#   Extracted table: keeper_stats_df9a10a1
#   Extracted table: shots_all
#   Extracted table: shots_2a6178ac
#   Extracted table: shots_df9a10a1
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [54/964] Downloading 23114faa...
# Downloading match 23114faa...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_23114faa.html (method: selenium)
#   Extracted table: stats_d976a235_summary
#   Extracted table: stats_d976a235_passing
#   Extracted table: stats_d976a235_passing_types
#   Extracted table: stats_d976a235_defense
#   Extracted table: stats_d976a235_possession
#   Extracted table: stats_d976a235_misc
#   Extracted table: keeper_stats_d976a235
#   Extracted table: stats_85c458aa_summary
#   Extracted table: stats_85c458aa_passing
#   Extracted table: stats_85c458aa_passing_types
#   Extracted table: stats_85c458aa_defense
#   Extracted table: stats_85c458aa_possession
#   Extracted table: stats_85c458aa_misc
#   Extracted table: keeper_stats_85c458aa
#   Extracted table: shots_all
#   Extracted table: shots_d976a235
#   Extracted table: shots_85c458aa
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [55/964] Downloading 37be7787...
# Downloading match 37be7787...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_37be7787.html (method: selenium)
#   Extracted table: stats_257fad2b_summary
#   Extracted table: stats_257fad2b_passing
#   Extracted table: stats_257fad2b_passing_types
#   Extracted table: stats_257fad2b_defense
#   Extracted table: stats_257fad2b_possession
#   Extracted table: stats_257fad2b_misc
#   Extracted table: keeper_stats_257fad2b
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: stats_8e306dc6_passing
#   Extracted table: stats_8e306dc6_passing_types
#   Extracted table: stats_8e306dc6_defense
#   Extracted table: stats_8e306dc6_possession
#   Extracted table: stats_8e306dc6_misc
#   Extracted table: keeper_stats_8e306dc6
#   Extracted table: shots_all
#   Extracted table: shots_257fad2b
#   Extracted table: shots_8e306dc6
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [56/964] Downloading d26ed7f0...
# Downloading match d26ed7f0...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_d26ed7f0.html (method: selenium)
#   Extracted table: stats_e442aad0_summary
#   Extracted table: stats_e442aad0_passing
#   Extracted table: stats_e442aad0_passing_types
#   Extracted table: stats_e442aad0_defense
#   Extracted table: stats_e442aad0_possession
#   Extracted table: stats_e442aad0_misc
#   Extracted table: keeper_stats_e442aad0
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: stats_df9a10a1_passing
#   Extracted table: stats_df9a10a1_passing_types
#   Extracted table: stats_df9a10a1_defense
#   Extracted table: stats_df9a10a1_possession
#   Extracted table: stats_df9a10a1_misc
#   Extracted table: keeper_stats_df9a10a1
#   Extracted table: shots_all
#   Extracted table: shots_e442aad0
#   Extracted table: shots_df9a10a1
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [57/964] Downloading 7f398f88...
# Downloading match 7f398f88...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_7f398f88.html (method: selenium)
#   Extracted table: stats_85c458aa_summary
#   Extracted table: stats_85c458aa_passing
#   Extracted table: stats_85c458aa_passing_types
#   Extracted table: stats_85c458aa_defense
#   Extracted table: stats_85c458aa_possession
#   Extracted table: stats_85c458aa_misc
#   Extracted table: keeper_stats_85c458aa
#   Extracted table: stats_d4c130bc_summary
#   Extracted table: stats_d4c130bc_passing
#   Extracted table: stats_d4c130bc_passing_types
#   Extracted table: stats_d4c130bc_defense
#   Extracted table: stats_d4c130bc_possession
#   Extracted table: stats_d4c130bc_misc
#   Extracted table: keeper_stats_d4c130bc
#   Extracted table: shots_all
#   Extracted table: shots_85c458aa
#   Extracted table: shots_d4c130bc
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [58/964] Downloading cc8ebaaa...
# Downloading match cc8ebaaa...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_cc8ebaaa.html (method: selenium)
#   Extracted table: stats_e813709a_summary
#   Extracted table: stats_e813709a_passing
#   Extracted table: stats_e813709a_passing_types
#   Extracted table: stats_e813709a_defense
#   Extracted table: stats_e813709a_possession
#   Extracted table: stats_e813709a_misc
#   Extracted table: keeper_stats_e813709a
#   Extracted table: stats_d976a235_summary
#   Extracted table: stats_d976a235_passing
#   Extracted table: stats_d976a235_passing_types
#   Extracted table: stats_d976a235_defense
#   Extracted table: stats_d976a235_possession
#   Extracted table: stats_d976a235_misc
#   Extracted table: keeper_stats_d976a235
#   Extracted table: shots_all
#   Extracted table: shots_e813709a
#   Extracted table: shots_d976a235
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [59/964] Downloading 0f1cb3d1...
# Downloading match 0f1cb3d1...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_0f1cb3d1.html (method: selenium)
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: stats_8e306dc6_passing
#   Extracted table: stats_8e306dc6_passing_types
#   Extracted table: stats_8e306dc6_defense
#   Extracted table: stats_8e306dc6_possession
#   Extracted table: stats_8e306dc6_misc
#   Extracted table: keeper_stats_8e306dc6
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: stats_df9a10a1_passing
#   Extracted table: stats_df9a10a1_passing_types
#   Extracted table: stats_df9a10a1_defense
#   Extracted table: stats_df9a10a1_possession
#   Extracted table: stats_df9a10a1_misc
#   Extracted table: keeper_stats_df9a10a1
#   Extracted table: shots_all
#   Extracted table: shots_8e306dc6
#   Extracted table: shots_df9a10a1
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [60/964] Downloading c79ee9c4...
# Downloading match c79ee9c4...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_c79ee9c4.html (method: selenium)
#   Extracted table: stats_d4c130bc_summary
#   Extracted table: stats_d4c130bc_passing
#   Extracted table: stats_d4c130bc_passing_types
#   Extracted table: stats_d4c130bc_defense
#   Extracted table: stats_d4c130bc_possession
#   Extracted table: stats_d4c130bc_misc
#   Extracted table: keeper_stats_d4c130bc
#   Extracted table: stats_2a6178ac_summary
#   Extracted table: stats_2a6178ac_passing
#   Extracted table: stats_2a6178ac_passing_types
#   Extracted table: stats_2a6178ac_defense
#   Extracted table: stats_2a6178ac_possession
#   Extracted table: stats_2a6178ac_misc
#   Extracted table: keeper_stats_2a6178ac
#   Extracted table: shots_all
#   Extracted table: shots_d4c130bc
#   Extracted table: shots_2a6178ac
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [61/964] Downloading 4120af97...
# Downloading match 4120af97...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_4120af97.html (method: selenium)
#   Extracted table: stats_d976a235_summary
#   Extracted table: stats_d976a235_passing
#   Extracted table: stats_d976a235_passing_types
#   Extracted table: stats_d976a235_defense
#   Extracted table: stats_d976a235_possession
#   Extracted table: stats_d976a235_misc
#   Extracted table: keeper_stats_d976a235
#   Extracted table: stats_e442aad0_summary
#   Extracted table: stats_e442aad0_passing
#   Extracted table: stats_e442aad0_passing_types
#   Extracted table: stats_e442aad0_defense
#   Extracted table: stats_e442aad0_possession
#   Extracted table: stats_e442aad0_misc
#   Extracted table: keeper_stats_e442aad0
#   Extracted table: shots_all
#   Extracted table: shots_d976a235
#   Extracted table: shots_e442aad0
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [62/964] Downloading 622f898e...
# Downloading match 622f898e...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_622f898e.html (method: selenium)
#   Extracted table: stats_257fad2b_summary
#   Extracted table: stats_257fad2b_passing
#   Extracted table: stats_257fad2b_passing_types
#   Extracted table: stats_257fad2b_defense
#   Extracted table: stats_257fad2b_possession
#   Extracted table: stats_257fad2b_misc
#   Extracted table: keeper_stats_257fad2b
#   Extracted table: stats_85c458aa_summary
#   Extracted table: stats_85c458aa_passing
#   Extracted table: stats_85c458aa_passing_types
#   Extracted table: stats_85c458aa_defense
#   Extracted table: stats_85c458aa_possession
#   Extracted table: stats_85c458aa_misc
#   Extracted table: keeper_stats_85c458aa
#   Extracted table: shots_all
#   Extracted table: shots_257fad2b
#   Extracted table: shots_85c458aa
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [63/964] Downloading f8c8aea4...
# Downloading match f8c8aea4...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_f8c8aea4.html (method: selenium)
#   Extracted table: stats_e442aad0_summary
#   Extracted table: stats_e442aad0_passing
#   Extracted table: stats_e442aad0_passing_types
#   Extracted table: stats_e442aad0_defense
#   Extracted table: stats_e442aad0_possession
#   Extracted table: stats_e442aad0_misc
#   Extracted table: keeper_stats_e442aad0
#   Extracted table: stats_d4c130bc_summary
#   Extracted table: stats_d4c130bc_passing
#   Extracted table: stats_d4c130bc_passing_types
#   Extracted table: stats_d4c130bc_defense
#   Extracted table: stats_d4c130bc_possession
#   Extracted table: stats_d4c130bc_misc
#   Extracted table: keeper_stats_d4c130bc
#   Extracted table: shots_all
#   Extracted table: shots_e442aad0
#   Extracted table: shots_d4c130bc
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [64/964] Downloading 6420bec8...
# Downloading match 6420bec8...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_6420bec8.html (method: selenium)
#   Extracted table: stats_2a6178ac_summary
#   Extracted table: stats_2a6178ac_passing
#   Extracted table: stats_2a6178ac_passing_types
#   Extracted table: stats_2a6178ac_defense
#   Extracted table: stats_2a6178ac_possession
#   Extracted table: stats_2a6178ac_misc
#   Extracted table: keeper_stats_2a6178ac
#   Extracted table: stats_85c458aa_summary
#   Extracted table: stats_85c458aa_passing
#   Extracted table: stats_85c458aa_passing_types
#   Extracted table: stats_85c458aa_defense
#   Extracted table: stats_85c458aa_possession
#   Extracted table: stats_85c458aa_misc
#   Extracted table: keeper_stats_85c458aa
#   Extracted table: shots_all
#   Extracted table: shots_2a6178ac
#   Extracted table: shots_85c458aa
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [65/964] Downloading 610a4c17...
# Downloading match 610a4c17...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_610a4c17.html (method: selenium)
#   Extracted table: stats_257fad2b_summary
#   Extracted table: stats_257fad2b_passing
#   Extracted table: stats_257fad2b_passing_types
#   Extracted table: stats_257fad2b_defense
#   Extracted table: stats_257fad2b_possession
#   Extracted table: stats_257fad2b_misc
#   Extracted table: keeper_stats_257fad2b
#   Extracted table: stats_e813709a_summary
#   Extracted table: stats_e813709a_passing
#   Extracted table: stats_e813709a_passing_types
#   Extracted table: stats_e813709a_defense
#   Extracted table: stats_e813709a_possession
#   Extracted table: stats_e813709a_misc
#   Extracted table: keeper_stats_e813709a
#   Extracted table: shots_all
#   Extracted table: shots_257fad2b
#   Extracted table: shots_e813709a
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [66/964] Downloading 1cef5979...
# Downloading match 1cef5979...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_1cef5979.html (method: selenium)
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: stats_df9a10a1_passing
#   Extracted table: stats_df9a10a1_passing_types
#   Extracted table: stats_df9a10a1_defense
#   Extracted table: stats_df9a10a1_possession
#   Extracted table: stats_df9a10a1_misc
#   Extracted table: keeper_stats_df9a10a1
#   Extracted table: stats_d976a235_summary
#   Extracted table: stats_d976a235_passing
#   Extracted table: stats_d976a235_passing_types
#   Extracted table: stats_d976a235_defense
#   Extracted table: stats_d976a235_possession
#   Extracted table: stats_d976a235_misc
#   Extracted table: keeper_stats_d976a235
#   Extracted table: shots_all
#   Extracted table: shots_df9a10a1
#   Extracted table: shots_d976a235
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [67/964] Downloading 888d23a0...
# Downloading match 888d23a0...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_888d23a0.html (method: selenium)
#   Extracted table: stats_85c458aa_summary
#   Extracted table: stats_85c458aa_passing
#   Extracted table: stats_85c458aa_passing_types
#   Extracted table: stats_85c458aa_defense
#   Extracted table: stats_85c458aa_possession
#   Extracted table: stats_85c458aa_misc
#   Extracted table: keeper_stats_85c458aa
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: stats_df9a10a1_passing
#   Extracted table: stats_df9a10a1_passing_types
#   Extracted table: stats_df9a10a1_defense
#   Extracted table: stats_df9a10a1_possession
#   Extracted table: stats_df9a10a1_misc
#   Extracted table: keeper_stats_df9a10a1
#   Extracted table: shots_all
#   Extracted table: shots_85c458aa
#   Extracted table: shots_df9a10a1
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [68/964] Downloading bde3da3d...
# Downloading match bde3da3d...
# ...
#   Extracted table: stats_df9a10a1_possession
#   Extracted table: stats_df9a10a1_misc
#   Extracted table: keeper_stats_df9a10a1
#   Extracted table: shots_all
#   Extracted table: shots_231a532f
#   Extracted table: shots_df9a10a1
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [948/964] Downloading 726a91eb...
# Downloading match 726a91eb...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_726a91eb.html (method: selenium)
#   Extracted table: stats_2a6178ac_summary
#   Extracted table: stats_2a6178ac_passing
#   Extracted table: stats_2a6178ac_passing_types
#   Extracted table: stats_2a6178ac_defense
#   Extracted table: stats_2a6178ac_possession
#   Extracted table: stats_2a6178ac_misc
#   Extracted table: keeper_stats_2a6178ac
#   Extracted table: stats_e813709a_summary
#   Extracted table: stats_e813709a_passing
#   Extracted table: stats_e813709a_passing_types
#   Extracted table: stats_e813709a_defense
#   Extracted table: stats_e813709a_possession
#   Extracted table: stats_e813709a_misc
#   Extracted table: keeper_stats_e813709a
#   Extracted table: shots_all
#   Extracted table: shots_2a6178ac
#   Extracted table: shots_e813709a
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [949/964] Downloading 230c5ecb...
# Downloading match 230c5ecb...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_230c5ecb.html (method: selenium)
#   Extracted table: stats_ae38d267_summary
#   Extracted table: stats_ae38d267_passing
#   Extracted table: stats_ae38d267_passing_types
#   Extracted table: stats_ae38d267_defense
#   Extracted table: stats_ae38d267_possession
#   Extracted table: stats_ae38d267_misc
#   Extracted table: keeper_stats_ae38d267
#   Extracted table: stats_d976a235_summary
#   Extracted table: stats_d976a235_passing
#   Extracted table: stats_d976a235_passing_types
#   Extracted table: stats_d976a235_defense
#   Extracted table: stats_d976a235_possession
#   Extracted table: stats_d976a235_misc
#   Extracted table: keeper_stats_d976a235
#   Extracted table: shots_all
#   Extracted table: shots_ae38d267
#   Extracted table: shots_d976a235
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [950/964] Downloading 60a0c5a1...
# Downloading match 60a0c5a1...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_60a0c5a1.html (method: selenium)
#   Extracted table: stats_e442aad0_summary
#   Extracted table: stats_e442aad0_passing
#   Extracted table: stats_e442aad0_passing_types
#   Extracted table: stats_e442aad0_defense
#   Extracted table: stats_e442aad0_possession
#   Extracted table: stats_e442aad0_misc
#   Extracted table: keeper_stats_e442aad0
#   Extracted table: stats_85c458aa_summary
#   Extracted table: stats_85c458aa_passing
#   Extracted table: stats_85c458aa_passing_types
#   Extracted table: stats_85c458aa_defense
#   Extracted table: stats_85c458aa_possession
#   Extracted table: stats_85c458aa_misc
#   Extracted table: keeper_stats_85c458aa
#   Extracted table: shots_all
#   Extracted table: shots_e442aad0
#   Extracted table: shots_85c458aa
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [951/964] Downloading 2e27ac56...
# Downloading match 2e27ac56...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_2e27ac56.html (method: selenium)
#   Extracted table: stats_231a532f_summary
#   Extracted table: stats_231a532f_passing
#   Extracted table: stats_231a532f_passing_types
#   Extracted table: stats_231a532f_defense
#   Extracted table: stats_231a532f_possession
#   Extracted table: stats_231a532f_misc
#   Extracted table: keeper_stats_231a532f
#   Extracted table: stats_2a6178ac_summary
#   Extracted table: stats_2a6178ac_passing
#   Extracted table: stats_2a6178ac_passing_types
#   Extracted table: stats_2a6178ac_defense
#   Extracted table: stats_2a6178ac_possession
#   Extracted table: stats_2a6178ac_misc
#   Extracted table: keeper_stats_2a6178ac
#   Extracted table: shots_all
#   Extracted table: shots_231a532f
#   Extracted table: shots_2a6178ac
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [952/964] Downloading ac197aa2...
# Downloading match ac197aa2...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_ac197aa2.html (method: selenium)
#   Extracted table: stats_e813709a_summary
#   Extracted table: stats_e813709a_passing
#   Extracted table: stats_e813709a_passing_types
#   Extracted table: stats_e813709a_defense
#   Extracted table: stats_e813709a_possession
#   Extracted table: stats_e813709a_misc
#   Extracted table: keeper_stats_e813709a
#   Extracted table: stats_bf961da0_summary
#   Extracted table: stats_bf961da0_passing
#   Extracted table: stats_bf961da0_passing_types
#   Extracted table: stats_bf961da0_defense
#   Extracted table: stats_bf961da0_possession
#   Extracted table: stats_bf961da0_misc
#   Extracted table: keeper_stats_bf961da0
#   Extracted table: shots_all
#   Extracted table: shots_e813709a
#   Extracted table: shots_bf961da0
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [953/964] Downloading 11ec0554...
# Downloading match 11ec0554...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_11ec0554.html (method: selenium)
#   Extracted table: stats_d4c130bc_summary
#   Extracted table: stats_d4c130bc_passing
#   Extracted table: stats_d4c130bc_passing_types
#   Extracted table: stats_d4c130bc_defense
#   Extracted table: stats_d4c130bc_possession
#   Extracted table: stats_d4c130bc_misc
#   Extracted table: keeper_stats_d4c130bc
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: stats_8e306dc6_passing
#   Extracted table: stats_8e306dc6_passing_types
#   Extracted table: stats_8e306dc6_defense
#   Extracted table: stats_8e306dc6_possession
#   Extracted table: stats_8e306dc6_misc
#   Extracted table: keeper_stats_8e306dc6
#   Extracted table: shots_all
#   Extracted table: shots_d4c130bc
#   Extracted table: shots_8e306dc6
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [954/964] Downloading fc4833e0...
# Downloading match fc4833e0...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_fc4833e0.html (method: selenium)
#   Extracted table: stats_d976a235_summary
#   Extracted table: stats_d976a235_passing
#   Extracted table: stats_d976a235_passing_types
#   Extracted table: stats_d976a235_defense
#   Extracted table: stats_d976a235_possession
#   Extracted table: stats_d976a235_misc
#   Extracted table: keeper_stats_d976a235
#   Extracted table: stats_257fad2b_summary
#   Extracted table: stats_257fad2b_passing
#   Extracted table: stats_257fad2b_passing_types
#   Extracted table: stats_257fad2b_defense
#   Extracted table: stats_257fad2b_possession
#   Extracted table: stats_257fad2b_misc
#   Extracted table: keeper_stats_257fad2b
#   Extracted table: shots_all
#   Extracted table: shots_d976a235
#   Extracted table: shots_257fad2b
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [955/964] Downloading 30d6a0e0...
# Downloading match 30d6a0e0...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_30d6a0e0.html (method: selenium)
#   Extracted table: stats_6f666306_summary
#   Extracted table: stats_6f666306_passing
#   Extracted table: stats_6f666306_passing_types
#   Extracted table: stats_6f666306_defense
#   Extracted table: stats_6f666306_possession
#   Extracted table: stats_6f666306_misc
#   Extracted table: keeper_stats_6f666306
#   Extracted table: stats_da19ebd1_summary
#   Extracted table: stats_da19ebd1_passing
#   Extracted table: stats_da19ebd1_passing_types
#   Extracted table: stats_da19ebd1_defense
#   Extracted table: stats_da19ebd1_possession
#   Extracted table: stats_da19ebd1_misc
#   Extracted table: keeper_stats_da19ebd1
#   Extracted table: shots_all
#   Extracted table: shots_6f666306
#   Extracted table: shots_da19ebd1
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [956/964] Downloading f06ed457...
# Downloading match f06ed457...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_f06ed457.html (method: selenium)
#   Extracted table: stats_ae38d267_summary
#   Extracted table: stats_ae38d267_passing
#   Extracted table: stats_ae38d267_passing_types
#   Extracted table: stats_ae38d267_defense
#   Extracted table: stats_ae38d267_possession
#   Extracted table: stats_ae38d267_misc
#   Extracted table: keeper_stats_ae38d267
#   Extracted table: stats_85c458aa_summary
#   Extracted table: stats_85c458aa_passing
#   Extracted table: stats_85c458aa_passing_types
#   Extracted table: stats_85c458aa_defense
#   Extracted table: stats_85c458aa_possession
#   Extracted table: stats_85c458aa_misc
#   Extracted table: keeper_stats_85c458aa
#   Extracted table: shots_all
#   Extracted table: shots_ae38d267
#   Extracted table: shots_85c458aa
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [957/964] Downloading 692f1ab8...
# Downloading match 692f1ab8...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_692f1ab8.html (method: selenium)
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: stats_df9a10a1_passing
#   Extracted table: stats_df9a10a1_passing_types
#   Extracted table: stats_df9a10a1_defense
#   Extracted table: stats_df9a10a1_possession
#   Extracted table: stats_df9a10a1_misc
#   Extracted table: keeper_stats_df9a10a1
#   Extracted table: stats_e442aad0_summary
#   Extracted table: stats_e442aad0_passing
#   Extracted table: stats_e442aad0_passing_types
#   Extracted table: stats_e442aad0_defense
#   Extracted table: stats_e442aad0_possession
#   Extracted table: stats_e442aad0_misc
#   Extracted table: keeper_stats_e442aad0
#   Extracted table: shots_all
#   Extracted table: shots_df9a10a1
#   Extracted table: shots_e442aad0
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [958/964] Downloading 91373610...
# Downloading match 91373610...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_91373610.html (method: selenium)
#   Extracted table: stats_6f666306_summary
#   Extracted table: stats_6f666306_passing
#   Extracted table: stats_6f666306_passing_types
#   Extracted table: stats_6f666306_defense
#   Extracted table: stats_6f666306_possession
#   Extracted table: stats_6f666306_misc
#   Extracted table: keeper_stats_6f666306
#   Extracted table: stats_ae38d267_summary
#   Extracted table: stats_ae38d267_passing
#   Extracted table: stats_ae38d267_passing_types
#   Extracted table: stats_ae38d267_defense
#   Extracted table: stats_ae38d267_possession
#   Extracted table: stats_ae38d267_misc
#   Extracted table: keeper_stats_ae38d267
#   Extracted table: shots_all
#   Extracted table: shots_6f666306
#   Extracted table: shots_ae38d267
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [959/964] Downloading 548d019f...
# Downloading match 548d019f...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_548d019f.html (method: selenium)
#   Extracted table: stats_da19ebd1_summary
#   Extracted table: stats_da19ebd1_passing
#   Extracted table: stats_da19ebd1_passing_types
#   Extracted table: stats_da19ebd1_defense
#   Extracted table: stats_da19ebd1_possession
#   Extracted table: stats_da19ebd1_misc
#   Extracted table: keeper_stats_da19ebd1
#   Extracted table: stats_2a6178ac_summary
#   Extracted table: stats_2a6178ac_passing
#   Extracted table: stats_2a6178ac_passing_types
#   Extracted table: stats_2a6178ac_defense
#   Extracted table: stats_2a6178ac_possession
#   Extracted table: stats_2a6178ac_misc
#   Extracted table: keeper_stats_2a6178ac
#   Extracted table: shots_all
#   Extracted table: shots_da19ebd1
#   Extracted table: shots_2a6178ac
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [960/964] Downloading 612a6c4c...
# Downloading match 612a6c4c...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_612a6c4c.html (method: selenium)
#   Extracted table: stats_d4c130bc_summary
#   Extracted table: stats_d4c130bc_passing
#   Extracted table: stats_d4c130bc_passing_types
#   Extracted table: stats_d4c130bc_defense
#   Extracted table: stats_d4c130bc_possession
#   Extracted table: stats_d4c130bc_misc
#   Extracted table: keeper_stats_d4c130bc
#   Extracted table: stats_257fad2b_summary
#   Extracted table: stats_257fad2b_passing
#   Extracted table: stats_257fad2b_passing_types
#   Extracted table: stats_257fad2b_defense
#   Extracted table: stats_257fad2b_possession
#   Extracted table: stats_257fad2b_misc
#   Extracted table: keeper_stats_257fad2b
#   Extracted table: shots_all
#   Extracted table: shots_d4c130bc
#   Extracted table: shots_257fad2b
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [961/964] Downloading 6be469ca...
# Downloading match 6be469ca...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_6be469ca.html (method: selenium)
#   Extracted table: stats_8e306dc6_summary
#   Extracted table: stats_8e306dc6_passing
#   Extracted table: stats_8e306dc6_passing_types
#   Extracted table: stats_8e306dc6_defense
#   Extracted table: stats_8e306dc6_possession
#   Extracted table: stats_8e306dc6_misc
#   Extracted table: keeper_stats_8e306dc6
#   Extracted table: stats_231a532f_summary
#   Extracted table: stats_231a532f_passing
#   Extracted table: stats_231a532f_passing_types
#   Extracted table: stats_231a532f_defense
#   Extracted table: stats_231a532f_possession
#   Extracted table: stats_231a532f_misc
#   Extracted table: keeper_stats_231a532f
#   Extracted table: shots_all
#   Extracted table: shots_8e306dc6
#   Extracted table: shots_231a532f
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [962/964] Downloading 14bc0f9a...
# Downloading match 14bc0f9a...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_14bc0f9a.html (method: selenium)
#   Extracted table: stats_85c458aa_summary
#   Extracted table: stats_85c458aa_passing
#   Extracted table: stats_85c458aa_passing_types
#   Extracted table: stats_85c458aa_defense
#   Extracted table: stats_85c458aa_possession
#   Extracted table: stats_85c458aa_misc
#   Extracted table: keeper_stats_85c458aa
#   Extracted table: stats_e813709a_summary
#   Extracted table: stats_e813709a_passing
#   Extracted table: stats_e813709a_passing_types
#   Extracted table: stats_e813709a_defense
#   Extracted table: stats_e813709a_possession
#   Extracted table: stats_e813709a_misc
#   Extracted table: keeper_stats_e813709a
#   Extracted table: shots_all
#   Extracted table: shots_85c458aa
#   Extracted table: shots_e813709a
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [963/964] Downloading d40c64aa...
# Downloading match d40c64aa...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_d40c64aa.html (method: selenium)
#   Extracted table: stats_df9a10a1_summary
#   Extracted table: stats_df9a10a1_passing
#   Extracted table: stats_df9a10a1_passing_types
#   Extracted table: stats_df9a10a1_defense
#   Extracted table: stats_df9a10a1_possession
#   Extracted table: stats_df9a10a1_misc
#   Extracted table: keeper_stats_df9a10a1
#   Extracted table: stats_d976a235_summary
#   Extracted table: stats_d976a235_passing
#   Extracted table: stats_d976a235_passing_types
#   Extracted table: stats_d976a235_defense
#   Extracted table: stats_d976a235_possession
#   Extracted table: stats_d976a235_misc
#   Extracted table: keeper_stats_d976a235
#   Extracted table: shots_all
#   Extracted table: shots_df9a10a1
#   Extracted table: shots_d976a235
# ✓ Success! Tables extracted: 17
# Waiting 10 seconds...
#
# [964/964] Downloading c56678cf...
# Downloading match c56678cf...
# Using Selenium for dynamic content...
# ✓ Successfully saved: match_c56678cf.html (method: selenium)
#   Extracted table: stats_bf961da0_summary
#   Extracted table: stats_bf961da0_passing
#   Extracted table: stats_bf961da0_passing_types
#   Extracted table: stats_bf961da0_defense
#   Extracted table: stats_bf961da0_possession
#   Extracted table: stats_bf961da0_misc
#   Extracted table: keeper_stats_bf961da0
#   Extracted table: stats_e442aad0_summary
#   Extracted table: stats_e442aad0_passing
#   Extracted table: stats_e442aad0_passing_types
#   Extracted table: stats_e442aad0_defense
#   Extracted table: stats_e442aad0_possession
#   Extracted table: stats_e442aad0_misc
#   Extracted table: keeper_stats_e442aad0
#   Extracted table: shots_all
#   Extracted table: shots_bf961da0
#   Extracted table: shots_e442aad0
# ✓ Success! Tables extracted: 17
#
# ============================================================
# Batch complete! Time: 295m 44s
# ✓ Successful: 962/964
# ✗ Failed: 2/964
# ============================================================

# %%
import sys
sys.path.append('../scripts')
from jupyter_extract_player_stats import extract_player_stats_by_matches

# Paste your match IDs here (as many as you want)
match_ids = [
    'f9e04c6f',
    '2de27dd8',
    '9d2567b5',
    # Keep adding match IDs - paste hundreds if needed
]

# Run the extraction with production features
extract_player_stats_by_matches(
    match_ids=match_ids,
    batch_name="My Match Extraction",
    log_filename="my_matches.log"
)
# Out:
# 2025-07-28 11:56:15,831 - INFO - Starting extraction for My Match Extraction
# 2025-07-28 11:56:15,832 - INFO - Logging to: /Users/thomasmcmillan/projects/nwsl_data/my_matches.log
# 2025-07-28 11:56:15,832 - INFO - Processing 3 match IDs: ['f9e04c6f', '2de27dd8', '9d2567b5']
# 2025-07-28 11:56:15,833 - INFO - Found 3 valid matches in database
# 2025-07-28 11:56:15,835 - INFO - Found 0 matches with existing player stats
# 2025-07-28 11:56:15,835 - INFO - Need to process 3 matches
# 2025-07-28 11:56:15,836 - INFO - ======================================================================
# 2025-07-28 11:56:15,836 - INFO - My Match Extraction - 2025-07-28 11:56:15
# 2025-07-28 11:56:15,836 - INFO - ======================================================================
# 2025-07-28 11:56:15,836 - INFO - Total matches: 3
# 2025-07-28 11:56:15,837 - INFO - Already extracted (skipping): 0
# 2025-07-28 11:56:15,837 - INFO - New matches to extract: 3
# 2025-07-28 11:56:15,837 - INFO - Extracting player stats from 3 matches...
# 2025-07-28 11:56:15,838 - INFO - Using comprehensive stats extraction with 3-12 second variable delays
# 2025-07-28 11:56:15,838 - INFO - Anti-blocking measures: randomized delays, extended pauses every 10 requests
# 2025-07-28 11:56:15,838 - INFO - Processing match 1/3: f9e04c6f (2023-10-15)
# 2025-07-28 11:56:15,838 - INFO - Scraping comprehensive player stats from: https://fbref.com/en/matches/f9e04c6f
# 2025-07-28 11:56:16,478 - INFO - Scraping comprehensive player stats from: https://fbref.com/en/matches/f9e04c6f
# 2025-07-28 11:56:29,752 - INFO - Processing table: stats_8e306dc6_summary
# 2025-07-28 11:56:29,755 - INFO - Processing table: stats_8e306dc6_passing
# 2025-07-28 11:56:29,756 - INFO - Processing table: stats_8e306dc6_passing_types
# 2025-07-28 11:56:29,759 - INFO - Processing table: stats_8e306dc6_defense
# 2025-07-28 11:56:29,762 - INFO - Processing table: stats_8e306dc6_possession
# 2025-07-28 11:56:29,763 - INFO - Processing table: stats_8e306dc6_misc
# 2025-07-28 11:56:29,765 - INFO - Processing table: stats_6f666306_summary
# 2025-07-28 11:56:29,766 - INFO - Processing table: stats_6f666306_passing
# 2025-07-28 11:56:29,768 - INFO - Processing table: stats_6f666306_passing_types
# 2025-07-28 11:56:29,770 - INFO - Processing table: stats_6f666306_defense
# 2025-07-28 11:56:29,771 - INFO - Processing table: stats_6f666306_possession
# 2025-07-28 11:56:52,357 - INFO - ✅ Successfully extracted stats for 28 players in match 9d2567b5
# 2025-07-28 11:56:52,357 - INFO - ======================================================================
# 2025-07-28 11:56:52,358 - INFO - EXTRACTION COMPLETE!
# 2025-07-28 11:56:52,358 - INFO - Batch: My Match Extraction
# 2025-07-28 11:56:52,358 - INFO - Duration: 0m 36s
# 2025-07-28 11:56:52,359 - INFO - Total matches processed: 3
# 2025-07-28 11:56:52,359 - INFO - ✓ Successful: 3
# 2025-07-28 11:56:52,359 - INFO - ✗ Errors: 0
# 2025-07-28 11:56:52,360 - INFO - Success rate: 100.0%
# 2025-07-28 11:56:52,360 - INFO - Average time per match: 12.2s
# 2025-07-28 11:56:52,361 - INFO - ======================================================================

# %%
# Import the production-ready extraction function
import sys
sys.path.append('../scripts')
from jupyter_extract_player_stats import extract_player_stats_by_matches

# Paste your match IDs here (as many as you want)
match_ids = [
    '5b076473',
    '9d04e156',
    'a4476197',
    '24e15195',
    '6dc65c5d'
]


# Run the extraction with clean print statements and production features
extract_player_stats_by_matches(
    match_ids=match_ids,
    batch_name="My Match Extraction",
    log_filename="my_matches.log"
)
# Out:
# 2025-07-28 11:59:55,161 - INFO - Starting extraction for My Match Extraction
# 2025-07-28 11:59:55,162 - INFO - Logging to: /Users/thomasmcmillan/projects/nwsl_data/my_matches.log
# 2025-07-28 11:59:55,162 - INFO - Processing 5 match IDs: ['5b076473', '9d04e156', 'a4476197', '24e15195', '6dc65c5d']
# 2025-07-28 11:59:55,164 - INFO - Found 5 valid matches in database
# 2025-07-28 11:59:55,165 - INFO - Found 0 matches with existing player stats
# 2025-07-28 11:59:55,166 - INFO - Need to process 5 matches
# 2025-07-28 11:59:55,166 - INFO - ======================================================================
# 2025-07-28 11:59:55,166 - INFO - My Match Extraction - 2025-07-28 11:59:55
# 2025-07-28 11:59:55,167 - INFO - ======================================================================
# 2025-07-28 11:59:55,167 - INFO - Total matches: 5
# 2025-07-28 11:59:55,167 - INFO - Already extracted (skipping): 0
# 2025-07-28 11:59:55,167 - INFO - New matches to extract: 5
# 2025-07-28 11:59:55,168 - INFO - Extracting player stats from 5 matches...
# 2025-07-28 11:59:55,168 - INFO - Using comprehensive stats extraction with 3-12 second variable delays
# 2025-07-28 11:59:55,168 - INFO - Anti-blocking measures: randomized delays, extended pauses every 10 requests
# 2025-07-28 11:59:55,168 - INFO - Processing match 1/5: 24e15195 (2023-10-15)
# 2025-07-28 11:59:55,168 - INFO - Scraping comprehensive player stats from: https://fbref.com/en/matches/24e15195
# 2025-07-28 11:59:56,039 - INFO - Scraping comprehensive player stats from: https://fbref.com/en/matches/24e15195
# 2025-07-28 11:59:58,170 - INFO - Processing table: stats_2a6178ac_summary
# 2025-07-28 11:59:58,173 - INFO - Processing table: stats_2a6178ac_passing
# 2025-07-28 11:59:58,176 - INFO - Processing table: stats_2a6178ac_passing_types
# 2025-07-28 11:59:58,179 - INFO - Processing table: stats_2a6178ac_defense
# 2025-07-28 11:59:58,186 - INFO - Processing table: stats_2a6178ac_possession
# 2025-07-28 11:59:58,194 - INFO - Processing table: stats_2a6178ac_misc
# 2025-07-28 11:59:58,196 - INFO - Processing table: stats_e813709a_summary
# 2025-07-28 11:59:58,200 - INFO - Processing table: stats_e813709a_passing
- INFO - Saved comprehensive stats for 31 players to database
# 2025-07-28 12:01:12,499 - INFO - ✅ Successfully extracted stats for 31 players in match a4476197
# 2025-07-28 12:01:12,499 - INFO - ======================================================================
# 2025-07-28 12:01:12,499 - INFO - EXTRACTION COMPLETE!
# 2025-07-28 12:01:12,500 - INFO - Batch: My Match Extraction
# 2025-07-28 12:01:12,500 - INFO - Duration: 1m 17s
# 2025-07-28 12:01:12,500 - INFO - Total matches processed: 5
# 2025-07-28 12:01:12,501 - INFO - ✓ Successful: 5
# 2025-07-28 12:01:12,501 - INFO - ✗ Errors: 0
# 2025-07-28 12:01:12,501 - INFO - Success rate: 100.0%
# 2025-07-28 12:01:12,502 - INFO - Average time per match: 15.5s
# 2025-07-28 12:01:12,502 - INFO - ======================================================================

# %%
# Import the production-ready extraction function
import sys
sys.path.append('../scripts')
from jupyter_extract_player_stats import extract_player_stats_by_matches

# Paste your match IDs here
match_ids = [
    '807c9e51',
    '6546a002',
    '63f04e4d',
    '162e58e3',
    'ffe3a6b6'
]


# Run the extraction with clean output
extract_player_stats_by_matches(
    match_ids=match_ids,
    batch_name="My Match Extraction",
    log_filename="my_matches.log"
)
# Out:
# 2025-07-28 12:03:40,608 - INFO - Starting extraction for My Match Extraction
# 2025-07-28 12:03:40,610 - INFO - Logging to: /Users/thomasmcmillan/projects/nwsl_data/my_matches.log
# 2025-07-28 12:03:40,610 - INFO - Processing 5 match IDs: ['807c9e51', '6546a002', '63f04e4d', '162e58e3', 'ffe3a6b6']
# 2025-07-28 12:03:40,612 - INFO - Found 5 valid matches in database
# 2025-07-28 12:03:40,615 - INFO - Found 0 matches with existing player stats
# 2025-07-28 12:03:40,616 - INFO - Need to process 5 matches
# 2025-07-28 12:03:40,616 - INFO - ======================================================================
# 2025-07-28 12:03:40,616 - INFO - My Match Extraction - 2025-07-28 12:03:40
# 2025-07-28 12:03:40,617 - INFO - ======================================================================
# 2025-07-28 12:03:40,617 - INFO - Total matches: 5
# 2025-07-28 12:03:40,617 - INFO - Already extracted (skipping): 0
# 2025-07-28 12:03:40,618 - INFO - New matches to extract: 5
# 2025-07-28 12:03:40,618 - INFO - Extracting player stats from 5 matches...
# 2025-07-28 12:03:40,618 - INFO - Using comprehensive stats extraction with 3-12 second variable delays
# 2025-07-28 12:03:40,619 - INFO - Anti-blocking measures: randomized delays, extended pauses every 10 requests
# 2025-07-28 12:03:40,620 - INFO - Processing match 1/5: 6546a002 (2023-10-06)
# 2025-07-28 12:03:40,620 - INFO - Scraping comprehensive player stats from: https://fbref.com/en/matches/6546a002
# 2025-07-28 12:03:41,276 - INFO - Scraping comprehensive player stats from: https://fbref.com/en/matches/6546a002
# 2025-07-28 12:03:53,483 - INFO - Processing table: stats_257fad2b_summary
# 2025-07-28 12:03:53,485 - INFO - Processing table: stats_257fad2b_passing
# 2025-07-28 12:03:53,487 - INFO - Processing table: stats_257fad2b_passing_types
# 2025-07-28 12:03:53,488 - INFO - Processing table: stats_257fad2b_defense
# 2025-07-28 12:03:53,489 - INFO - Processing table: stats_257fad2b_possession
# 2025-07-28 12:03:53,490 - INFO - Processing table: stats_257fad2b_misc
# 2025-07-28 12:03:53,492 - INFO - Processing table: stats_e442aad0_summary
# 2025-07-28 12:03:53,494 - INFO - Processing table: stats_e442aad0_passing
# 2025-07-28 12:03:53,495 - INFO - Processing table: stats_e442aad0_passing_types
# 2025-07-28 12:05:13,775 - INFO - Saved comprehensive stats for 30 players to database
# 2025-07-28 12:05:13,775 - INFO - ✅ Successfully extracted stats for 30 players in match 162e58e3
# 2025-07-28 12:05:13,776 - INFO - ======================================================================
# 2025-07-28 12:05:13,776 - INFO - EXTRACTION COMPLETE!
# 2025-07-28 12:05:13,777 - INFO - Batch: My Match Extraction
# 2025-07-28 12:05:13,777 - INFO - Duration: 1m 33s
# 2025-07-28 12:05:13,777 - INFO - Total matches processed: 5
# 2025-07-28 12:05:13,778 - INFO - ✓ Successful: 5
# 2025-07-28 12:05:13,778 - INFO - ✗ Errors: 0
# 2025-07-28 12:05:13,778 - INFO - Success rate: 100.0%
# 2025-07-28 12:05:13,779 - INFO - Average time per match: 18.6s
# 2025-07-28 12:05:13,779 - INFO - ======================================================================

# %%
# Import the production-ready extraction function
import sys
sys.path.append('../scripts')
from jupyter_extract_player_stats import extract_player_stats_by_matches

# Paste your match IDs here
match_ids = [
    '22b9918f',
    '0c66c1c4',
    '9d816b1c',
    '9467b1af',
    '42534159',
    '076238c6',
    'e0c9fd2f'
]


# Extract player stats for these matches
extract_player_stats_by_matches(
    match_ids, 
    batch_name="Player Stats Extraction",
    log_filename="player_stats_extraction.log"
)
# Out:
# 2025-07-28 12:15:57,111 - INFO - Starting extraction for Player Stats Extraction
# 2025-07-28 12:15:57,112 - INFO - Logging to: /Users/thomasmcmillan/projects/nwsl_data/player_stats_extraction.log
# 2025-07-28 12:15:57,113 - INFO - Processing 7 match IDs: ['22b9918f', '0c66c1c4', '9d816b1c', '9467b1af', '42534159', '076238c6', 'e0c9fd2f']
# 2025-07-28 12:15:57,114 - INFO - Found 7 valid matches in database
# 2025-07-28 12:15:57,118 - INFO - Found 0 matches with existing player stats
# 2025-07-28 12:15:57,119 - INFO - Need to process 7 matches
# 2025-07-28 12:15:57,119 - INFO - ======================================================================
# 2025-07-28 12:15:57,120 - INFO - Player Stats Extraction - 2025-07-28 12:15:57
# 2025-07-28 12:15:57,120 - INFO - ======================================================================
# 2025-07-28 12:15:57,120 - INFO - Total matches: 7
# 2025-07-28 12:15:57,120 - INFO - Already extracted (skipping): 0
# 2025-07-28 12:15:57,121 - INFO - New matches to extract: 7
# 2025-07-28 12:15:57,121 - INFO - Extracting player stats from 7 matches...
# 2025-07-28 12:15:57,121 - INFO - Using comprehensive stats extraction with 3-12 second variable delays
# 2025-07-28 12:15:57,122 - INFO - Anti-blocking measures: randomized delays, extended pauses every 10 requests
# 2025-07-28 12:15:57,122 - INFO - Processing match 1/7: 22b9918f (2023-09-30)
# 2025-07-28 12:15:57,123 - INFO - Scraping comprehensive player stats from: https://fbref.com/en/matches/22b9918f
# 2025-07-28 12:15:57,780 - INFO - Scraping comprehensive player stats from: https://fbref.com/en/matches/22b9918f
# 2025-07-28 12:15:59,930 - INFO - Processing table: stats_e442aad0_summary
# 2025-07-28 12:15:59,932 - INFO - Processing table: stats_e442aad0_passing
# 2025-07-28 12:15:59,935 - INFO - Processing table: stats_e442aad0_passing_types
# 2025-07-28 12:15:59,936 - INFO - Processing table: stats_e442aad0_defense
# 2025-07-28 12:15:59,941 - INFO - Processing table: stats_e442aad0_possession
# 2025-07-28 12:15:59,943 - INFO - Processing table: stats_e442aad0_misc
# 2025-07-28 12:15:59,947 - INFO - Processing table: stats_6f666306_summary
- INFO - Extracted comprehensive stats for 31 players
# 2025-07-28 12:18:21,765 - INFO - Saved comprehensive stats for 31 players to database
# 2025-07-28 12:18:21,766 - INFO - ✅ Successfully extracted stats for 31 players in match e0c9fd2f
# 2025-07-28 12:18:21,766 - INFO - ======================================================================
# 2025-07-28 12:18:21,766 - INFO - EXTRACTION COMPLETE!
# 2025-07-28 12:18:21,766 - INFO - Batch: Player Stats Extraction
# 2025-07-28 12:18:21,767 - INFO - Duration: 2m 24s
# 2025-07-28 12:18:21,767 - INFO - Total matches processed: 7
# 2025-07-28 12:18:21,768 - INFO - ✓ Successful: 7
# 2025-07-28 12:18:21,768 - INFO - ✗ Errors: 0
# 2025-07-28 12:18:21,768 - INFO - Success rate: 100.0%
# 2025-07-28 12:18:21,768 - INFO - Average time per match: 20.7s
# 2025-07-28 12:18:21,769 - INFO - ======================================================================

# %%
# Import the extraction function from the same directory
from jupyter_extract_player_stats import extract_player_stats_by_matches

# Paste your match IDs here
match_ids = [
    '5b076473',
    '9d04e156',
    'a4476197',
    '24e15195',
    '6dc65c5d'
]

# Extract player stats for these matches
extract_player_stats_by_matches(
    match_ids, 
    batch_name="Player Stats Extraction",
    log_filename="player_stats_extraction.log"
)
# Out:
# 2025-07-28 12:19:30,313 - INFO - Starting extraction for Player Stats Extraction
# 2025-07-28 12:19:30,314 - INFO - Logging to: /Users/thomasmcmillan/projects/nwsl_data/player_stats_extraction.log
# 2025-07-28 12:19:30,315 - INFO - Processing 5 match IDs: ['5b076473', '9d04e156', 'a4476197', '24e15195', '6dc65c5d']
# 2025-07-28 12:19:30,317 - INFO - Found 5 valid matches in database
# 2025-07-28 12:19:30,320 - INFO - Found 5 matches with existing player stats
# 2025-07-28 12:19:30,321 - INFO - Need to process 0 matches
# 2025-07-28 12:19:30,321 - INFO - ======================================================================
# 2025-07-28 12:19:30,322 - INFO - Player Stats Extraction - 2025-07-28 12:19:30
# 2025-07-28 12:19:30,322 - INFO - ======================================================================
# 2025-07-28 12:19:30,322 - INFO - Total matches: 5
# 2025-07-28 12:19:30,323 - INFO - Already extracted (skipping): 5
# 2025-07-28 12:19:30,323 - INFO - New matches to extract: 0
# 2025-07-28 12:19:30,323 - INFO - ✓ All matches already extracted! Nothing to do.

# %%
# Suppress console logging
import logging
logging.getLogger().handlers = []

# Import the extraction function
from jupyter_extract_player_stats import extract_player_stats_by_matches

# Paste your match IDs here
match_ids = [
    '5b076473',
    '9d04e156',
    'a4476197',
    '24e15195',
    '6dc65c5d'
]

# Extract player stats for these matches
extract_player_stats_by_matches(
    match_ids, 
    batch_name="Player Stats Extraction",
    log_filename="player_stats_extraction.log"
)
# Out:
# 2025-07-28 12:20:10,027 - INFO - Starting extraction for Player Stats Extraction
# 2025-07-28 12:20:10,029 - INFO - Logging to: /Users/thomasmcmillan/projects/nwsl_data/player_stats_extraction.log
# 2025-07-28 12:20:10,030 - INFO - Processing 5 match IDs: ['5b076473', '9d04e156', 'a4476197', '24e15195', '6dc65c5d']
# 2025-07-28 12:20:10,032 - INFO - Found 5 valid matches in database
# 2025-07-28 12:20:10,036 - INFO - Found 5 matches with existing player stats
# 2025-07-28 12:20:10,037 - INFO - Need to process 0 matches
# 2025-07-28 12:20:10,037 - INFO - ======================================================================
# 2025-07-28 12:20:10,038 - INFO - Player Stats Extraction - 2025-07-28 12:20:10
# 2025-07-28 12:20:10,038 - INFO - ======================================================================
# 2025-07-28 12:20:10,039 - INFO - Total matches: 5
# 2025-07-28 12:20:10,039 - INFO - Already extracted (skipping): 5
# 2025-07-28 12:20:10,040 - INFO - New matches to extract: 0
# 2025-07-28 12:20:10,041 - INFO - ✓ All matches already extracted! Nothing to do.

# %%
# Import the extraction function
from jupyter_extract_player_stats import extract_player_stats_by_matches

# Paste your match IDs here
match_ids = [
    '5b076473',
    '9d04e156',
    'a4476197',
    '24e15195',
    '6dc65c5d'
]

# Temporarily disable all logging to console
import logging
import sys

# Save current logging configuration
original_handlers = logging.root.handlers[:]
original_level = logging.root.level

# Clear all handlers and set level to only show CRITICAL messages
logging.root.handlers = []
logging.root.setLevel(logging.CRITICAL)

try:
    # Extract player stats for these matches
    extract_player_stats_by_matches(
        match_ids, 
        batch_name="Player Stats Extraction",
        log_filename="player_stats_extraction.log"
    )
finally:
    # Restore original logging configuration
    logging.root.handlers = original_handlers
    logging.root.setLevel(original_level)
# Out:
# 2025-07-28 12:21:22,289 - INFO - Starting extraction for Player Stats Extraction
# 2025-07-28 12:21:22,291 - INFO - Logging to: /Users/thomasmcmillan/projects/nwsl_data/player_stats_extraction.log
# 2025-07-28 12:21:22,291 - INFO - Processing 5 match IDs: ['5b076473', '9d04e156', 'a4476197', '24e15195', '6dc65c5d']
# 2025-07-28 12:21:22,293 - INFO - Found 5 valid matches in database
# 2025-07-28 12:21:22,295 - INFO - Found 5 matches with existing player stats
# 2025-07-28 12:21:22,296 - INFO - Need to process 0 matches
# 2025-07-28 12:21:22,297 - INFO - ======================================================================
# 2025-07-28 12:21:22,297 - INFO - Player Stats Extraction - 2025-07-28 12:21:22
# 2025-07-28 12:21:22,298 - INFO - ======================================================================
# 2025-07-28 12:21:22,298 - INFO - Total matches: 5
# 2025-07-28 12:21:22,298 - INFO - Already extracted (skipping): 5
# 2025-07-28 12:21:22,299 - INFO - New matches to extract: 0
# 2025-07-28 12:21:22,300 - INFO - ✓ All matches already extracted! Nothing to do.

# %%
# Import the extraction function
from jupyter_extract_player_stats import extract_player_stats_by_matches

# Your match IDs
match_ids = [
    'cc8f4050',
    '0359e2a8',
    '02cc2db8',
    '32b74c42',
    '8777bb7e'
]


# Extract player stats
extract_player_stats_by_matches(
    match_ids, 
    batch_name="Player Stats Extraction",
    log_filename="player_stats_extraction.log"
)
# Out:
# 2025-07-28 12:30:22,209 - INFO - Starting extraction for Player Stats Extraction
# 2025-07-28 12:30:22,211 - INFO - Logging to: /Users/thomasmcmillan/projects/nwsl_data/player_stats_extraction.log
# 2025-07-28 12:30:22,211 - INFO - Processing 5 match IDs: ['cc8f4050', '0359e2a8', '02cc2db8', '32b74c42', '8777bb7e']
# 2025-07-28 12:30:22,214 - INFO - Found 5 valid matches in database
# 2025-07-28 12:30:22,218 - INFO - Found 0 matches with existing player stats
# 2025-07-28 12:30:22,219 - INFO - Need to process 5 matches
# 2025-07-28 12:30:22,219 - INFO - ======================================================================
# 2025-07-28 12:30:22,220 - INFO - Player Stats Extraction - 2025-07-28 12:30:22
# 2025-07-28 12:30:22,220 - INFO - ======================================================================
# 2025-07-28 12:30:22,220 - INFO - Total matches: 5
- INFO - Scraping comprehensive player stats from: https://fbref.com/en/matches/8777bb7e
# 2025-07-28 12:31:20,353 - INFO - Scraping comprehensive player stats from: https://fbref.com/en/matches/8777bb7e
# 2025-07-28 12:31:22,260 - INFO - Processing table: stats_85c458aa_summary
# 2025-07-28 12:31:22,262 - INFO - Processing table: stats_85c458aa_passing
# 2025-07-28 12:31:22,264 - INFO - Processing table: stats_85c458aa_passing_types
# 2025-07-28 12:31:22,266 - INFO - Processing table: stats_85c458aa_defense
# 2025-07-28 12:31:22,267 - INFO - Processing table: stats_85c458aa_possession
# 2025-07-28 12:31:22,270 - INFO - Processing table: stats_85c458aa_misc
# 2025-07-28 12:31:22,272 - INFO - Processing table: stats_8e306dc6_summary
# 2025-07-28 12:31:22,275 - INFO - Processing table: stats_8e306dc6_passing
# 2025-07-28 12:31:22,280 - INFO - Processing table: stats_8e306dc6_passing_types
# 2025-07-28 12:31:22,284 - INFO - Processing table: stats_8e306dc6_defense
# 2025-07-28 12:31:22,287 - INFO - Processing table: stats_8e306dc6_possession
# 2025-07-28 12:31:22,296 - INFO - Processing table: stats_8e306dc6_misc
# 2025-07-28 12:31:22,299 - INFO - Extracted comprehensive stats for 29 players
# 2025-07-28 12:31:22,383 - INFO - Saved comprehensive stats for 29 players to database
# 2025-07-28 12:31:22,384 - INFO - ✅ Successfully extracted stats for 29 players in match 8777bb7e
# 2025-07-28 12:31:22,384 - INFO - ======================================================================
# 2025-07-28 12:31:22,385 - INFO - EXTRACTION COMPLETE!
# 2025-07-28 12:31:22,385 - INFO - Batch: Player Stats Extraction
# 2025-07-28 12:31:22,386 - INFO - Duration: 1m 0s
# 2025-07-28 12:31:22,386 - INFO - Total matches processed: 5
# 2025-07-28 12:31:22,386 - INFO - ✓ Successful: 5
# 2025-07-28 12:31:22,387 - INFO - ✗ Errors: 0
# 2025-07-28 12:31:22,387 - INFO - Success rate: 100.0%
# 2025-07-28 12:31:22,387 - INFO - Average time per match: 12.0s
# 2025-07-28 12:31:22,388 - INFO - ======================================================================

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (from requests) (2025.7.14)

# %%
import requests
import json
import time
import csv
from typing import List, Dict, Tuple
import pandas as pd  # For better display in Jupyter

class WolframCityDataFetcher:
    def __init__(self, api_key: str):
        self.api_key = api_key
        self.base_url = "https://api.wolframalpha.com/v2/query"
        
    def fetch_city_data(self, city: str, state: str) -> Dict:
        """Fetch comprehensive data for a single city"""
        
        params = {
            'appid': self.api_key,
            'input': f"{city}, {state}",
            'format': 'plaintext',
            'output': 'JSON',
            'includepodid': 'Location:CityData,Population:CityData,Demographics:USCityData,EconomicProperties:CityData,GeographicProperties:CityData'
        }
        
        try:
            response = requests.get(self.base_url, params=params)
            response.raise_for_status()
            return response.json()
        except requests.exceptions.RequestException as e:
            print(f"Error fetching data for {city}, {state}: {e}")
            return None
    
    def parse_city_data(self, data: Dict) -> Dict:
        """Extract relevant information from Wolfram Alpha response"""
        
        if not data or not data.get('queryresult', {}).get('success'):
            return {"error": "Query failed"}
        
        parsed_data = {}
        pods = data['queryresult'].get('pods', [])
        
        for pod in pods:
            pod_id = pod.get('id', '')
            pod_title = pod.get('title', '')
            
            # Extract plaintext from subpods
            subpods = pod.get('subpods', [])
            if subpods and subpods[0].get('plaintext'):
                content = subpods[0]['plaintext']
                
                # Parse based on pod type
                if 'Population' in pod_id:
                    parsed_data['population'] = self._parse_population(content)
                elif 'Demographics' in pod_id:
                    parsed_data['demographics'] = self._parse_demographics(content)
                elif 'EconomicProperties' in pod_id:
                    parsed_data['economic'] = self._parse_economic(content)
                elif 'GeographicProperties' in pod_id:
                    parsed_data['geographic'] = self._parse_geographic(content)
                elif 'Location' in pod_id:
                    parsed_data['location'] = content
        
        return parsed_data
    
    def _parse_population(self, content: str) -> Dict:
        """Parse population data from plaintext"""
        data = {}
        lines = content.strip().split('\n')
        
        for line in lines:
            if '|' in line:
                parts = line.split('|')
                if len(parts) >= 2:
                    key = parts[0].strip()
                    value = parts[1].strip()
                    data[key] = value
        
        return data
    
    def _parse_demographics(self, content: str) -> Dict:
        """Parse demographic data from plaintext"""
        return {"raw": content}
    
    def _parse_economic(self, content: str) -> Dict:
        """Parse economic data from plaintext"""
        return {"raw": content}
    
    def _parse_geographic(self, content: str) -> Dict:
        """Parse geographic data from plaintext"""
        return {"raw": content}
    
    def fetch_multiple_cities(self, cities: List[Tuple[str, str]], delay: float = 1.0) -> List[Dict]:
        """Fetch data for multiple cities with rate limiting"""
        
        results = []
        
        for i, (city, state) in enumerate(cities):
            print(f"Fetching data for {city}, {state} ({i+1}/{len(cities)})...")
            
            # Fetch raw data
            raw_data = self.fetch_city_data(city, state)
            
            # Parse the data
            if raw_data:
                parsed = self.parse_city_data(raw_data)
                parsed['city'] = city
                parsed['state'] = state
                results.append(parsed)
            else:
                results.append({
                    'city': city,
                    'state': state,
                    'error': 'Failed to fetch data'
                })
            
            # Rate limiting (except for last city)
            if i < len(cities) - 1:
                time.sleep(delay)
        
        return results
    
    def save_to_csv(self, data: List[Dict], filename: str = 'city_data.csv'):
        """Save parsed data to CSV file"""
        
        if not data:
            print("No data to save")
            return
        
        # Flatten nested dictionaries for CSV
        flattened_data = []
        
        for city_data in data:
            flat_row = {
                'city': city_data.get('city'),
                'state': city_data.get('state'),
                'location': city_data.get('location', 'N/A')
            }
            
            # Add population data
            if 'population' in city_data:
                for key, value in city_data['population'].items():
                    flat_row[f'population_{key}'] = value
            
            flattened_data.append(flat_row)
        
        # Write to CSV
        if flattened_data:
            keys = set()
            for row in flattened_data:
                keys.update(row.keys())
            
            with open(filename, 'w', newline='', encoding='utf-8') as f:
                writer = csv.DictWriter(f, fieldnames=sorted(keys))
                writer.writeheader()
                writer.writerows(flattened_data)
            
            print(f"Data saved to {filename}")
    
    def save_to_json(self, data: List[Dict], filename: str = 'city_data.json'):
        """Save parsed data to JSON file"""
        
        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(data, f, indent=2)
        
        print(f"Data saved to {filename}")

# %%
API_KEY = "8APYYV624R"
    
# List of cities to fetch
cities = [
    ("Cary", "NC"),
]

# %%
# Initialize fetcher
fetcher = WolframCityDataFetcher(API_KEY)

# Fetch data for all cities
results = fetcher.fetch_multiple_cities(cities, 1.5)

print(f"\n✅ Fetched data for {len(results)} cities")
successful = sum(1 for r in results if 'error' not in r)
print(f"Successful: {successful}")
print(f"Failed: {len(results) - successful}")
# Out:
# Fetching data for Cary, NC (1/1)...
#
# ✅ Fetched data for 1 cities
# Successful: 1
# Failed: 0

# %%
# Display first city's data as example
if results:
    print("Sample data for first city:")
    print(json.dumps(results[0], indent=2))
# Out:
# Sample data for first city:
# {
#   "city": "Cary",
#   "state": "NC"
# }

# %%
# Create a simplified DataFrame for viewing
def flatten_for_df(results):
    rows = []
    for r in results:
        row = {
            'City': r.get('city'),
            'State': r.get('state'),
            'Location': r.get('location', 'N/A')
        }
        
        # Add population data if available
        if 'population' in r and isinstance(r['population'], dict):
            for k, v in r['population'].items():
                row[f'Pop: {k}'] = v
        
        rows.append(row)
    
    return pd.DataFrame(rows)

df = flatten_for_df(results)
display(df)  # or just 'df' in Jupyter
# Out:
#    City State Location
# 0  Cary    NC      N/A

# %%
# Debug: Check the raw response for one city
test_city = "Cary"
test_state = "NC"

params = {
    'appid': API_KEY,
    'input': f"{test_city}, {test_state}",
    'format': 'plaintext',
    'output': 'JSON'
}

response = requests.get("https://api.wolframalpha.com/v2/query", params=params)
raw_data = response.json()

# Check if query was successful
print(f"Success: {raw_data['queryresult'].get('success')}")
print(f"Number of pods: {len(raw_data['queryresult'].get('pods', []))}")

# List all available pods
print("\nAvailable pods:")
for pod in raw_data['queryresult'].get('pods', []):
    print(f"  - {pod['title']} (ID: {pod['id']})")
# Out:
# Success: True
# Number of pods: 21
#
# Available pods:
#   - Input interpretation (ID: Input)
#   - Populations (ID: Population:CityData)
#   - Location (ID: Location:CityData)
#   - Local map (ID: Map:CityData)
#   - Administrative regions (ID: AdministrativeRegions:CityData)
#   - Current local time (ID: CurrentTime:CityData)
#   - Current weather (ID: WeatherPod:CityData)
#   - Demographics (ID: ACSPercentageEntrainments:ACSData)
#   - Educational attainment (ID: ACSEducationEntrainments:ACSData)
#   - Income statistics (ID: ACSIncomeEntrainments:ACSData)
#   - Economic properties (ID: EconomicProperties:CityData)
#   - Other indicators (ID: QualityOfLife:CityData)
#   - Nearby cities (ID: CityHierarchyInfo:CityData)
#   - Nearby airport (ID: AirportHierarchyInfo:CityData)
#   - Nearby hospital (ID: HospitalHierarchyInfo:CityData)
#   - Notable company headquarters (ID: CompaniesInCity:CityData)
#   - Geographic properties (ID: GeographicProperties:CityData)
#   - Nearby features (ID: FeaturesHierarchyInfo:CityData)
#   - Nearest sea (ID: OceansHierarchyInfo:CityData)
#   - Notable people born in Cary (ID: NotablePeople:CityData)
#   - Wikipedia page hits history (ID: PopularityPod:WikipediaStatsData)

# %%
# Run this in a Jupyter cell to install required packages
# !pip install requests pandas openpyxl
# Out:
# Requirement already satisfied: requests in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (2.32.4)
# Requirement already satisfied: pandas in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (2.3.1)
# Requirement already satisfied: openpyxl in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (3.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (from requests) (2025.7.14)
# Requirement already satisfied: numpy>=1.26.0 in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /Users/thomasmcmillan/projects/nwsl_data/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Import the module
from wolfram_city_fetcher import fetch_city_data

# ===== CONFIGURATION =====
# Your Wolfram Alpha API key
API_KEY = "8APYYV624R"

# Enter your cities here (City, State abbreviation)
CITIES = [
    ("Washington", "D.C.")
]

# Optional: Change output file prefix (default is "city_data")
OUTPUT_PREFIX = "city_data"

# ===== RUN THE FETCHER =====
results, excel_file, json_file, csv_file = fetch_city_data(
    api_key=API_KEY,
    cities=CITIES,
    output_prefix=OUTPUT_PREFIX
)

# ===== VIEW RESULTS =====
# Display summary of results
print("\n📊 Quick Summary:")
for result in results[:5]:  # Show first 5 cities
    if 'error' not in result:
        city_name = f"{result['city']}, {result['state']}"
        pop = result.get('populations', {}).get('city population', 'N/A') if isinstance(result.get('populations'), dict) else 'N/A'
        print(f"  {city_name}: Population = {pop}")

# Optional: Load and display the summary DataFrame
import pandas as pd
df = pd.read_csv(csv_file)
print("\n📋 Summary Table:")
display(df.head())
# Out:
# 🏙️  WOLFRAM ALPHA CITY DATA FETCHER
# ==================================================
#
# 🚀 Starting to fetch data for 1 cities...
# 📋 Fields to fetch: populations, demographics, education_attainment, income_statistics, economic_properties, nearby_cities, geographic_properties
#
# 📍 Fetching data for Washington, D.C. (1/1)...
#    ✅ Success! Found 7 fields: populations, demographics, education_attainment, income_statistics, economic_properties, nearby_cities, geographic_properties
#
# 📊 SUMMARY:
# ========================================
# ✅ Successfully fetched: 1 cities
# ❌ Failed: 0 cities
#
# 💾 Saving data...
# ✅ Excel report saved to: city_data.xlsx
# ✅ Complete JSON data saved to: city_data.json
# ✅ Summary CSV saved to: city_data_summary.csv
#
# 🎉 All done! Your data has been saved:
#    📊 city_data.xlsx - Excel with multiple sheets
#    📄 city_data.json - Complete raw data
#    📋 city_data_summary.csv - Summary metrics
#
# 📊 Quick Summary:
#   Washington, D.C.: Population = 689545 people (country rank: 20th) (2020 estimate)
#
# 📋 Summary Table:
#          City State Data_Status  \
# 0  Washington  D.C.     Success
#
#                                      City_Population  \
# 0  689545 people (country rank: 20th) (2020 estim...
#
#                                     Metro_Population  \
# 0  5.704 million people (Washington (DC) metro ar...
#
#                                     Urban_Population  \
# 0  3.934 million people (Washington (DC) urban ar...
#
#                                            Demo_race Demo_Hispanic origin  \
# 0  black/African American: 46.3% | white: 41.3% |...                  11%
#
#   Demo_US citizens              College_Degree_Plus  ...  \
# 0            92.3%  61.5% (1.51 × national average)  ...
#
#                              Median_Household_Income  \
# 0  $86420.00 per year (US dollars per year) (1.38...
#
#                                    Per_Capita_Income  \
# 0  $56147 per year per person (US dollars per yea...
#
#                       Poverty_Rate  \
# 0  16.2% (1.21 × national average)
#
#                                    Median_Home_Price Unemployment_Rate  \
# 0  $637400.00 (Washington (DC) metro area) (annua...  6.2% (June 2025)
#
#        Sales_Tax_Rate         Area Elevation            Population_Density  \
# 0  6% (2025 estimate)  61.048 mi^2     23 ft  11295 people per square mile
#
#   Nearby_Cities_Count
# 0                   3
#
# [1 rows x 21 columns]
